# %% [markdown]
# ## The fifth In-class-exercise (9/30/2020, 20 points in total)

# %% [markdown]
# In exercise-03, I asked you to collected 500 textual data based on your own information needs (If you didn't collect the textual data, you should recollect for this exercise). Now we need to think about how to represent the textual data for text classification. In this exercise, you are required to select 10 types of features (10 types of features but absolutely more than 10 features) in the followings feature list, then represent the 500 texts with these features. The output should be in the following format:
# ![image.png](attachment:image.png)
#
# The feature list:
#
# * (1) tf-idf features
# * (2) POS-tag features: number of adjective, adverb, auxiliary, punctuation, complementizer, coordinating conjunction, subordinating conjunction, determiner, interjection, noun, possessor, preposition, pronoun, quantifier, verb, and other. (select some of them if you use pos-tag features)
# * (3) Linguistic features:
#   * number of right-branching nodes across all constituent types
#   * number of right-branching nodes for NPs only
#   * number of left-branching nodes across all constituent types
#   * number of left-branching nodes for NPs only
#   * number of premodifiers across all constituent types
#   * number of premodifiers within NPs only
#   * number of postmodifiers across all constituent types
#   * number of postmodifiers within NPs only
#   * branching index across all constituent types, i.e. the number of right-branching nodes minus number of left-branching nodes
#   * branching index for NPs only
#   * branching weight index: number of tokens covered by right-branching nodes minus number of tokens covered by left-branching nodes across all categories
#   * branching weight index for NPs only
#   * modification index, i.e. the number of premodifiers minus the number of postmodifiers across all categories
#   * modification index for NPs only
#   * modification weight index: length in tokens of all premodifiers minus length in tokens of all postmodifiers across all categories
#   * modification weight index for NPs only
#   * coordination balance, i.e. the maximal length difference in coordinated constituents
#
#   * density (density can be calculated using the ratio of folowing function words to content words) of determiners/quantifiers
#   * density of pronouns
#   * density of prepositions
#   * density of punctuation marks, specifically commas and semicolons
#   * density of auxiliary verbs
#   * density of conjunctions
#   * density of different pronoun types: Wh, 1st, 2nd, and 3rd person pronouns
#
#   * maximal and average NP length
#   * maximal and average AJP length
#   * maximal and average PP length
#   * maximal and average AVP length
#   * sentence length
#
# * Other features in your mind (ie., pre-defined patterns)

# %% [markdown]
# # **Extracting Data**

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
main_text = [] # List to store Review headings
sub_text =[] #List to store reviews
for number in range(52):
  link = "https://www.flipkart.com/apple-iphone-11-black-64-gb/product-reviews/itm4e5041ba101fd?pid=MOBFWQ6BXGJCEYNY&lid=LSTMOBFWQ6BXGJCEYNYZE3ENS&marketplace=FLIPKART&page=" + str(number) # Generating link dynamically
  page = requests.get(link) # Accessing the webpage
  soup = BeautifulSoup(page.text, 'html.parser')
  main_reviews = soup.find_all(class_='_2-N8zT') # Getting the Review Heading by using the class name
  text_reviews = soup.find_all(class_='t-ZTKy') # Getting the full reviews by using the class name
  for ele, sub_ele in zip(main_reviews, text_reviews) : # Iterating through the list
      main_text.append(ele.text) #Appending to empty list
      sub_text.append(sub_ele.text)
df = pd.DataFrame(list(zip(main_text, sub_text)), columns =['Glimpse of Review', 'Full Review'])  # Creating Dataframe
print("Length of data frame is {0}".format(len(df)))
df
# Out:
# Length of data frame is 510
#          Glimpse of Review                                        Full Review
# 0                Brilliant  The Best Phone for the MoneyThe iPhone 11 offe...
# 1         Perfect product!  Amazing phone with great cameras and better ba...
# 2            Great product  Amazing Powerful and Durable Gadget.I’m am ver...
# 3        Worth every penny  Previously I was using one plus 3t it was a gr...
# 4              Good choice  So far it’s been an AMAZING experience coming ...
# ..                     ...                                                ...
# 505       Perfect product!  Original product for apple and security seal p...
# 506  Mind-blowing purchase  Good phone by apple battery is far better ( on...
# 507              Brilliant                                   Love itREAD MORE
# 508       Perfect product!  All are good not giving charger and earphones ...
# 509     Highly recommended  Decided to buy Iphone 11 over Iphone xr, and a...
#
# [510 rows x 2 columns]

# %% [markdown]
# # **Preprocessing Data**

# %% [markdown]
# **Converting to lower case**

# %%
df['After Preprocessing'] = df['Full Review'].apply(lambda x: " ".join(x.lower() for x in x.split()))
df
# Out:
#          Glimpse of Review  ...                                After Preprocessing
# 0                Brilliant  ...  the best phone for the moneythe iphone 11 offe...
# 1         Perfect product!  ...  amazing phone with great cameras and better ba...
# 2            Great product  ...  amazing powerful and durable gadget.i’m am ver...
# 3        Worth every penny  ...  previously i was using one plus 3t it was a gr...
# 4              Good choice  ...  so far it’s been an amazing experience coming ...
# ..                     ...  ...                                                ...
# 505       Perfect product!  ...  original product for apple and security seal p...
# 506  Mind-blowing purchase  ...  good phone by apple battery is far better ( on...
# 507              Brilliant  ...                                   love itread more
# 508       Perfect product!  ...  all are good not giving charger and earphones ...
# 509     Highly recommended  ...  decided to buy iphone 11 over iphone xr, and a...
#
# [510 rows x 3 columns]

# %% [markdown]
# **Removing Punctuation**

# %%
df['After Preprocessing'] = df['After Preprocessing'].str.replace('[^\w\s]','')
df
# Out:
#          Glimpse of Review  ...                                After Preprocessing
# 0                Brilliant  ...  the best phone for the moneythe iphone 11 offe...
# 1         Perfect product!  ...  amazing phone with great cameras and better ba...
# 2            Great product  ...  amazing powerful and durable gadgetim am very ...
# 3        Worth every penny  ...  previously i was using one plus 3t it was a gr...
# 4              Good choice  ...  so far its been an amazing experience coming b...
# ..                     ...  ...                                                ...
# 505       Perfect product!  ...  original product for apple and security seal p...
# 506  Mind-blowing purchase  ...  good phone by apple battery is far better  one...
# 507              Brilliant  ...                                   love itread more
# 508       Perfect product!  ...  all are good not giving charger and earphones ...
# 509     Highly recommended  ...  decided to buy iphone 11 over iphone xr and af...
#
# [510 rows x 3 columns]

# %% [markdown]
# **Removing Numerics**

# %%
df['After Preprocessing'] = df['After Preprocessing'].apply(lambda x: ''.join([i for i in x if not i.isdigit()]))

# %% [markdown]
# **Removing Special Characters**

# %%
import re
df['After Preprocessing'] = df['After Preprocessing'].apply(lambda x: ''.join(re.sub(r"[^a-zA-Z0-9]+", ' ', charctr) for charctr in x ))
df
# Out:
#          Glimpse of Review  ...                                After Preprocessing
# 0                Brilliant  ...  the best phone for the moneythe iphone  offers...
# 1         Perfect product!  ...  amazing phone with great cameras and better ba...
# 2            Great product  ...  amazing powerful and durable gadgetim am very ...
# 3        Worth every penny  ...  previously i was using one plus t it was a gre...
# 4              Good choice  ...  so far its been an amazing experience coming b...
# ..                     ...  ...                                                ...
# 505       Perfect product!  ...  original product for apple and security seal p...
# 506  Mind-blowing purchase  ...  good phone by apple battery is far better  one...
# 507              Brilliant  ...                                   love itread more
# 508       Perfect product!  ...  all are good not giving charger and earphones ...
# 509     Highly recommended  ...  decided to buy iphone  over iphone xr and afte...
#
# [510 rows x 3 columns]

# %%
import nltk
nltk.download()
# Out:
# NLTK Downloader
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> c
#
# Data Server:
#   - URL: <https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml>
#   - 7 Package Collections Available
#   - 107 Individual Packages Available
#
# Local Machine:
#   - Data directory: /root/nltk_data
#
# ---------------------------------------------------------------------------
#     s) Show Config   u) Set Server URL   d) Set Data Dir   m) Main Menu
# ---------------------------------------------------------------------------
# Config> m
#
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> d
#
# Download which package (l=list; x=cancel)?
#   Identifier> all
#     Downloading collection 'all'
#        |
#        | Downloading package abc to /root/nltk_data...
#        |   Unzipping corpora/abc.zip.
#        | Downloading package alpino to /root/nltk_data...
#        |   Unzipping corpora/alpino.zip.
#        | Downloading package biocreative_ppi to /root/nltk_data...
#        |   Unzipping corpora/biocreative_ppi.zip.
#        | Downloading package brown to /root/nltk_data...
#        |   Unzipping corpora/brown.zip.
#        | Downloading package brown_tei to /root/nltk_data...
#        |   Unzipping corpora/brown_tei.zip.
#        | Downloading package cess_cat to /root/nltk_data...
#        |   Unzipping corpora/cess_cat.zip.
#        | Downloading package cess_esp to /root/nltk_data...
#        |   Unzipping corpora/cess_esp.zip.
#        | Downloading package chat80 to /root/nltk_data...
#        |   Unzipping corpora/chat80.zip.
#        | Downloading package city_database to /root/nltk_data...
#        |   Unzipping corpora/city_database.zip.
#        | Downloading package cmudict to /root/nltk_data...
#        |   Unzipping corpora/cmudict.zip.
#        | Downloading package comparative_sentences to
#        |     /root/nltk_data...
#        |   Unzipping corpora/comparative_sentences.zip.
#        | Downloading package comtrans to /root/nltk_data...
#        | Downloading package conll2000 to /root/nltk_data...
#        |   Unzipping corpora/conll2000.zip.
#        | Downloading package conll2002 to /root/nltk_data...
#        |   Unzipping corpora/conll2002.zip.
#        | Downloading package conll2007 to /root/nltk_data...
#        | Downloading package crubadan to /root/nltk_data...
#        |   Unzipping corpora/crubadan.zip.
#        | Downloading package dependency_treebank to /root/nltk_data...
#        |   Unzipping corpora/dependency_treebank.zip.
#        | Downloading package dolch to /root/nltk_data...
#        |   Unzipping corpora/dolch.zip.
#        | Downloading package europarl_raw to /root/nltk_data...
#        |   Unzipping corpora/europarl_raw.zip.
#        | Downloading package floresta to /root/nltk_data...
#        |   Unzipping corpora/floresta.zip.
#        | Downloading package framenet_v15 to /root/nltk_data...
#        |   Unzipping corpora/framenet_v15.zip.
#        | Downloading package framenet_v17 to /root/nltk_data...
#        |   Unzipping corpora/framenet_v17.zip.
#        | Downloading package gazetteers to /root/nltk_data...
#        |   Unzipping corpora/gazetteers.zip.
#        | Downloading package genesis to /root/nltk_data...
#        |   Unzipping corpora/genesis.zip.
#        | Downloading package gutenberg to /root/nltk_data...
#        |   Unzipping corpora/gutenberg.zip.
#        | Downloading package ieer to /root/nltk_data...
#        |   Unzipping corpora/ieer.zip.
#        | Downloading package inaugural to /root/nltk_data...
#        |   Unzipping corpora/inaugural.zip.
#        | Downloading package indian to /root/nltk_data...
#        |   Unzipping corpora/indian.zip.
#        | Downloading package jeita to /root/nltk_data...
#        | Downloading package kimmo to /root/nltk_data...
#        |   Unzipping corpora/kimmo.zip.
#        | Downloading package knbc to /root/nltk_data...
#        | Downloading package lin_thesaurus to /root/nltk_data...
#        |   Unzipping corpora/lin_thesaurus.zip.
#        | Downloading package mac_morpho to /root/nltk_data...
#        |   Unzipping corpora/mac_morpho.zip.
#        | Downloading package machado to /root/nltk_data...
#        | Downloading package masc_tagged to /root/nltk_data...
#        | Downloading package moses_sample to /root/nltk_data...
#        |   Unzipping models/moses_sample.zip.
#        | Downloading package movie_reviews to /root/nltk_data...
#        |   Unzipping corpora/movie_reviews.zip.
#        | Downloading package names to /root/nltk_data...
#        |   Unzipping corpora/names.zip.
#        | Downloading package nombank.1.0 to /root/nltk_data...
#        | Downloading package nps_chat to /root/nltk_data...
#        |   Unzipping corpora/nps_chat.zip.
#        | Downloading package omw to /root/nltk_data...
#        |   Unzipping corpora/omw.zip.
#        | Downloading package opinion_lexicon to /root/nltk_data...
#        |   Unzipping corpora/opinion_lexicon.zip.
#        | Downloading package paradigms to /root/nltk_data...
#        |   Unzipping corpora/paradigms.zip.
#        | Downloading package pil to /root/nltk_data...
#        |   Unzipping corpora/pil.zip.
#        | Downloading package pl196x to /root/nltk_data...
#        |   Unzipping corpora/pl196x.zip.
#        | Downloading package ppattach to /root/nltk_data...
#        |   Unzipping corpora/ppattach.zip.
#        | Downloading package problem_reports to /root/nltk_data...
#        |   Unzipping corpora/problem_reports.zip.
#        | Downloading package propbank to /root/nltk_data...
#        | Downloading package ptb to /root/nltk_data...
#        |   Unzipping corpora/ptb.zip.
#        | Downloading package product_reviews_1 to /root/nltk_data...
#        |   Unzipping corpora/product_reviews_1.zip.
#        | Downloading package product_reviews_2 to /root/nltk_data...
#        |   Unzipping corpora/product_reviews_2.zip.
#        | Downloading package pros_cons to /root/nltk_data...
#        |   Unzipping corpora/pros_cons.zip.
#        | Downloading package qc to /root/nltk_data...
#        |   Unzipping corpora/qc.zip.
#        | Downloading package reuters to /root/nltk_data...
#        | Downloading package rte to /root/nltk_data...
#        |   Unzipping corpora/rte.zip.
#        | Downloading package semcor to /root/nltk_data...
#        | Downloading package senseval to /root/nltk_data...
#        |   Unzipping corpora/senseval.zip.
#        | Downloading package sentiwordnet to /root/nltk_data...
#        |   Unzipping corpora/sentiwordnet.zip.
#        | Downloading package sentence_polarity to /root/nltk_data...
#        |   Unzipping corpora/sentence_polarity.zip.
#        | Downloading package shakespeare to /root/nltk_data...
#        |   Unzipping corpora/shakespeare.zip.
#        | Downloading package sinica_treebank to /root/nltk_data...
#        |   Unzipping corpora/sinica_treebank.zip.
#        | Downloading package smultron to /root/nltk_data...
#        |   Unzipping corpora/smultron.zip.
#        | Downloading package state_union to /root/nltk_data...
#        |   Unzipping corpora/state_union.zip.
#        | Downloading package stopwords to /root/nltk_data...
#        |   Unzipping corpora/stopwords.zip.
#        | Downloading package subjectivity to /root/nltk_data...
#        |   Unzipping corpora/subjectivity.zip.
#        | Downloading package swadesh to /root/nltk_data...
#        |   Unzipping corpora/swadesh.zip.
#        | Downloading package switchboard to /root/nltk_data...
#        |   Unzipping corpora/switchboard.zip.
#        | Downloading package timit to /root/nltk_data...
#        |   Unzipping corpora/timit.zip.
#        | Downloading package toolbox to /root/nltk_data...
#        |   Unzipping corpora/toolbox.zip.
#        | Downloading package treebank to /root/nltk_data...
#        |   Unzipping corpora/treebank.zip.
#        | Downloading package twitter_samples to /root/nltk_data...
#        |   Unzipping corpora/twitter_samples.zip.
#        | Downloading package udhr to /root/nltk_data...
#        |   Unzipping corpora/udhr.zip.
#        | Downloading package udhr2 to /root/nltk_data...
#        |   Unzipping corpora/udhr2.zip.
#        | Downloading package unicode_samples to /root/nltk_data...
#        |   Unzipping corpora/unicode_samples.zip.
#        | Downloading package universal_treebanks_v20 to
#        |     /root/nltk_data...
#        | Downloading package verbnet to /root/nltk_data...
#        |   Unzipping corpora/verbnet.zip.
#        | Downloading package verbnet3 to /root/nltk_data...
#        |   Unzipping corpora/verbnet3.zip.
#        | Downloading package webtext to /root/nltk_data...
#        |   Unzipping corpora/webtext.zip.
#        | Downloading package wordnet to /root/nltk_data...
#        |   Unzipping corpora/wordnet.zip.
#        | Downloading package wordnet_ic to /root/nltk_data...
#        |   Unzipping corpora/wordnet_ic.zip.
#        | Downloading package words to /root/nltk_data...
#        |   Unzipping corpora/words.zip.
#        | Downloading package ycoe to /root/nltk_data...
#        |   Unzipping corpora/ycoe.zip.
#        | Downloading package rslp to /root/nltk_data...
#        |   Unzipping stemmers/rslp.zip.
#        | Downloading package maxent_treebank_pos_tagger to
#        |     /root/nltk_data...
#        |   Unzipping taggers/maxent_treebank_pos_tagger.zip.
#        | Downloading package universal_tagset to /root/nltk_data...
#        |   Unzipping taggers/universal_tagset.zip.
#        | Downloading package maxent_ne_chunker to /root/nltk_data...
#        |   Unzipping chunkers/maxent_ne_chunker.zip.
#        | Downloading package punkt to /root/nltk_data...
#        |   Unzipping tokenizers/punkt.zip.
#        | Downloading package book_grammars to /root/nltk_data...
#        |   Unzipping grammars/book_grammars.zip.
#        | Downloading package sample_grammars to /root/nltk_data...
#        |   Unzipping grammars/sample_grammars.zip.
#        | Downloading package spanish_grammars to /root/nltk_data...
#        |   Unzipping grammars/spanish_grammars.zip.
#        | Downloading package basque_grammars to /root/nltk_data...
#        |   Unzipping grammars/basque_grammars.zip.
#        | Downloading package large_grammars to /root/nltk_data...
#        |   Unzipping grammars/large_grammars.zip.
#        | Downloading package tagsets to /root/nltk_data...
#        |   Unzipping help/tagsets.zip.
#        | Downloading package snowball_data to /root/nltk_data...
#        | Downloading package bllip_wsj_no_aux to /root/nltk_data...
#        |   Unzipping models/bllip_wsj_no_aux.zip.
#        | Downloading package word2vec_sample to /root/nltk_data...
#        |   Unzipping models/word2vec_sample.zip.
#        | Downloading package panlex_swadesh to /root/nltk_data...
#        | Downloading package mte_teip5 to /root/nltk_data...
#        |   Unzipping corpora/mte_teip5.zip.
#        | Downloading package averaged_perceptron_tagger to
#        |     /root/nltk_data...
#        |   Unzipping taggers/averaged_perceptron_tagger.zip.
#        | Downloading package averaged_perceptron_tagger_ru to
#        |     /root/nltk_data...
#        |   Unzipping taggers/averaged_perceptron_tagger_ru.zip.
#        | Downloading package perluniprops to /root/nltk_data...
#        |   Unzipping misc/perluniprops.zip.
#        | Downloading package nonbreaking_prefixes to
#        |     /root/nltk_data...
#        |   Unzipping corpora/nonbreaking_prefixes.zip.
#        | Downloading package vader_lexicon to /root/nltk_data...
#        | Downloading package porter_test to /root/nltk_data...
#        |   Unzipping stemmers/porter_test.zip.
#        | Downloading package wmt15_eval to /root/nltk_data...
#        |   Unzipping models/wmt15_eval.zip.
#        | Downloading package mwa_ppdb to /root/nltk_data...
#        |   Unzipping misc/mwa_ppdb.zip.
#        |
#      Done downloading collection all
#
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> q
# True

# %% [markdown]
# **Removing Stop Words**

# %%
from nltk.corpus import stopwords
stop = stopwords.words('english')
df['After Preprocessing'] = df['After Preprocessing'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))
df
# Out:
#          Glimpse of Review  ...                                After Preprocessing
# 0                Brilliant  ...  best phone moneythe iphone offers superb camer...
# 1         Perfect product!  ...  amazing phone great cameras better battery giv...
# 2            Great product  ...  amazing powerful durable gadgetim happy camera...
# 3        Worth every penny  ...  previously using one plus great phone decided ...
# 4              Good choice  ...  far amazing experience coming back ios nearly ...
# ..                     ...  ...                                                ...
# 505       Perfect product!  ...  original product apple security seal pack flip...
# 506  Mind-blowing purchase  ...  good phone apple battery far better one kidney...
# 507              Brilliant  ...                                        love itread
# 508       Perfect product!  ...                 good giving charger earphones read
# 509     Highly recommended  ...  decided buy iphone iphone xr using week dont r...
#
# [510 rows x 3 columns]

# %% [markdown]
# **Spelling Correction**

# %%
from textblob import TextBlob
df['After Preprocessing'].apply(lambda x: str(TextBlob(x).correct()))
# Out:
# 0      best phone moneythe phone offers superb camera...
# 1      amazing phone great camera better battery give...
# 2      amazing powerful unable gadgetim happy camera ...
# 3      previously using one plus great phone decided ...
# 4      far amazing experience coming back is nearly d...
#                              ...
# 505    original product apple security seal pack flip...
# 506    good phone apple battery far better one kidney...
# 507                                           love tread
# 508                    good giving charge earphones read
# 509    decided buy phone phone or using week dont reg...
# Name: After Preprocessing, Length: 510, dtype: object

# %% [markdown]
# **Stemming**

# %%
from nltk.stem import PorterStemmer
st = PorterStemmer()
df['After Preprocessing'].apply(lambda x: " ".join([st.stem(word) for word in x.split()]))
# Out:
# 0      best phone moneyth iphon offer superb camera d...
# 1      amaz phone great camera better batteri give be...
# 2      amaz power durabl gadgetim happi camera pictur...
# 3      previous use one plu great phone decid upgrad ...
# 4      far amaz experi come back io nearli decad vers...
#                              ...
# 505    origin product appl secur seal pack flipcart i...
# 506    good phone appl batteri far better one kidney ...
# 507                                          love itread
# 508                       good give charger earphon read
# 509    decid buy iphon iphon xr use week dont regret ...
# Name: After Preprocessing, Length: 510, dtype: object

# %% [markdown]
# **Lemmatization**

# %%
from textblob import Word
import nltk
nltk.download('wordnet')

df['After Preprocessing'] = df['After Preprocessing'].apply(lambda x: " ".join([Word(word).lemmatize() for word in x.split()]))
df
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
#          Glimpse of Review  ...                                After Preprocessing
# 0                Brilliant  ...  best phone moneythe iphone offer superb camera...
# 1         Perfect product!  ...  amazing phone great camera better battery give...
# 2            Great product  ...  amazing powerful durable gadgetim happy camera...
# 3        Worth every penny  ...  previously using one plus great phone decided ...
# 4              Good choice  ...  far amazing experience coming back io nearly d...
# ..                     ...  ...                                                ...
# 505       Perfect product!  ...  original product apple security seal pack flip...
# 506  Mind-blowing purchase  ...  good phone apple battery far better one kidney...
# 507              Brilliant  ...                                        love itread
# 508       Perfect product!  ...                  good giving charger earphone read
# 509     Highly recommended  ...  decided buy iphone iphone xr using week dont r...
#
# [510 rows x 3 columns]

# %% [markdown]
# # **Parts of Speech Tagging and Features**

# %%
from nltk.tokenize import word_tokenize
pos = []
for sentence in df['After Preprocessing']:
  text = word_tokenize(sentence)
  pos.append(nltk.pos_tag(text))
pos
# Out:
# [[('best', 'JJS'),
#   ('phone', 'NN'),
#   ('moneythe', 'NN'),
#   ('iphone', 'NN'),
#   ('offer', 'NN'),
#   ('superb', 'NN'),
#   ('camera', 'NN'),
#   ('durable', 'JJ'),
#   ('design', 'NN'),
#   ('excellent', 'JJ'),
#   ('battery', 'NN'),
#   ('life', 'NN'),
#   ('affordable', 'JJ'),
#   ('pricecompelling', 'VBG'),
#   ('ultrawide', 'JJ'),
#   ('cameranew', 'NN'),
#   ('night', 'NN'),
#   ('mode', 'NN'),
#   ('excellentlong', 'JJ'),
#   ('battery', 'NN'),
#   ('liferead', 'NN')],
#  [('amazing', 'VBG'),
#   ('phone', 'NN'),
#   ('great', 'JJ'),
#   ('camera', 'NN'),
#   ('better', 'RBR'),
#   ('battery', 'NN'),
#   ('give', 'JJ'),
#   ('best', 'RBS'),
#   ('performance', 'NN'),
#   ('love', 'NN'),
#   ('camera', 'NN'),
#   ('read', 'NN')],
#  [('amazing', 'VBG'),
#   ('powerful', 'JJ'),
#   ('durable', 'JJ'),
#   ('gadgetim', 'NN'),
#   ('happy', 'JJ'),
#   ('camera', 'NN'),
#   ('picture', 'NN'),
#   ('quality', 'NN'),
#   ('amazing', 'VBG'),
#   ('face', 'NN'),
#   ('id', 'NN'),
#   ('unlocked', 'VBD'),
#   ('dark', 'JJ'),
#   ('room', 'NN'),
#   ('strong', 'JJ'),
#   ('battery', 'NN'),
#   ('perfect', 'NN'),
#   ('screen', 'NN'),
#   ('size', 'NN'),
#   ('carry', 'VBP'),
#   ('easily', 'RB'),
#   ('pocket', 'JJ'),
#   ('third', 'JJ'),
#   ('iphone', 'NN'),
#   ('shifted', 'VBD'),
#   ('android', 'JJ'),
#   ('samsung', 'NN'),
#   ('note', 'NN'),
#   ('series', 'NN'),
#   ('iphone', 'NN'),
#   ('strong', 'JJ'),
#   ('build', 'JJ'),
#   ('quality', 'NN'),
#   ('peace', 'NN'),
#   ('mind', 'NN'),
#   ('next', 'JJ'),
#   ('yearsdont', 'NN'),
#   ('think', 'VBP'),
#   ('much', 'RB'),
#   ('go', 'VB'),
#   ('suggest', 'RB'),
#   ('go', 'RB'),
#   ('minimum', 'JJ'),
#   ('gb', 'NN'),
#   ('variant', 'NN'),
#   ('gb', 'NN'),
#   ('ive', 'JJ'),
#   ('attached', 'VBN'),
#   ('puppy', 'JJ'),
#   ('pic', 'NN'),
#   ('firead', 'NN')],
#  [('previously', 'RB'),
#   ('using', 'VBG'),
#   ('one', 'CD'),
#   ('plus', 'CC'),
#   ('great', 'JJ'),
#   ('phone', 'NN'),
#   ('decided', 'VBD'),
#   ('upgrade', 'JJ'),
#   ('stuck', 'NN'),
#   ('samsung', 'NN'),
#   ('plus', 'CC'),
#   ('iphone', 'NN'),
#   ('seen', 'VBN'),
#   ('spec', 'JJ'),
#   ('everything', 'NN'),
#   ('good', 'JJ'),
#   ('except', 'IN'),
#   ('display', 'NN'),
#   ('somewhere', 'RB'),
#   ('even', 'RB'),
#   ('amoled', 'VBD'),
#   ('lcd', 'JJ'),
#   ('display', 'NN'),
#   ('decided', 'VBD'),
#   ('go', 'VB'),
#   ('iphone', 'NN'),
#   ('never', 'RB'),
#   ('used', 'VBD'),
#   ('io', 'JJ'),
#   ('device', 'NN'),
#   ('android', 'IN'),
#   ('user', 'NN'),
#   ('past', 'IN'),
#   ('year', 'NN'),
#   ('ordered', 'VBD'),
#   ('iphone', 'NN'),
#   ('gb', 'NN'),
#   ('product', 'NN'),
#   ('redmy', 'NN'),
#   ('experience', 'NN'),
#   ('using', 'VBG'),
#   ('week', 'NN'),
#   ('delivery', 'NN'),
#   ('read', 'NN')],
#  [('far', 'RB'),
#   ('amazing', 'JJ'),
#   ('experience', 'NN'),
#   ('coming', 'VBG'),
#   ('back', 'RB'),
#   ('io', 'RB'),
#   ('nearly', 'RB'),
#   ('decade', 'NN'),
#   ('versatile', 'JJ'),
#   ('android', 'JJ'),
#   ('though', 'IN'),
#   ('phone', 'NN'),
#   ('sturdy', 'NN'),
#   ('dropped', 'VBD'),
#   ('accidentally', 'RB'),
#   ('couple', 'JJ'),
#   ('time', 'NN'),
#   ('nothing', 'NN'),
#   ('happened', 'VBD'),
#   ('fortunately', 'RB'),
#   ('camera', 'JJ'),
#   ('awesomeread', 'NN')],
#  [('iphone', 'RB'),
#   ('good', 'JJ'),
#   ('phone', 'NN'),
#   ('buy', 'VBP'),
#   ('compromise', 'NN'),
#   ('display', 'NN'),
#   ('display', 'NN'),
#   ('device', 'NN'),
#   ('pretty', 'RB'),
#   ('good', 'JJ'),
#   ('get', 'NN'),
#   ('option', 'NN'),
#   ('better', 'RBR'),
#   ('display', 'NN'),
#   ('price', 'NN'),
#   ('segmentif', 'NN'),
#   ('survive', 'JJ'),
#   ('hd', 'NN'),
#   ('lcd', 'JJ'),
#   ('panel', 'NN'),
#   ('thicker', 'NN'),
#   ('bezel', 'NN'),
#   ('notch', 'NN'),
#   ('top', 'NN'),
#   ('good', 'JJ'),
#   ('phone', 'NN'),
#   ('youcameras', 'NNS'),
#   ('awesome', 'JJ'),
#   ('battery', 'NN'),
#   ('backup', 'NN'),
#   ('excellent', 'JJ'),
#   ('great', 'JJ'),
#   ('performance', 'NN'),
#   ('decent', 'JJ'),
#   ('premium', 'JJ'),
#   ('look', 'NN'),
#   ('good', 'JJ'),
#   ('job', 'NN'),
#   ('apple', 'NN'),
#   ('read', 'NN')],
#  [('must', 'MD'),
#   ('buy', 'VB'),
#   ('looking', 'VBG'),
#   ('upgrade', 'JJ'),
#   ('previous', 'JJ'),
#   ('generation', 'NN'),
#   ('iphones', 'NNS'),
#   ('using', 'VBG'),
#   ('xr', 'NN'),
#   ('still', 'RB'),
#   ('hold', 'VB'),
#   ('sometime', 'RB'),
#   ('upgrade', 'JJ'),
#   ('model', 'NN'),
#   ('else', 'RB'),
#   ('phone', 'NN'),
#   ('must', 'MD'),
#   ('buy', 'VB'),
#   ('camera', 'NN'),
#   ('quality', 'NN'),
#   ('amazing', 'VBG'),
#   ('wide', 'JJ'),
#   ('angle', 'NN'),
#   ('something', 'NN'),
#   ('count', 'NN'),
#   ('upon', 'IN'),
#   ('performance', 'NN'),
#   ('wise', 'NN'),
#   ('amazing', 'VBG'),
#   ('feel', 'NN'),
#   ('premium', 'JJ'),
#   ('holding', 'VBG'),
#   ('hand', 'NN'),
#   ('big', 'JJ'),
#   ('yes', 'NN'),
#   ('device', 'NN'),
#   ('go', 'VBP'),
#   ('gb', 'NN'),
#   ('variant', 'NN'),
#   ('k', 'NN'),
#   ('video', 'NN'),
#   ('occupy', 'NN'),
#   ('lot', 'NN'),
#   ('space', 'NN'),
#   ('storage', 'NN'),
#   ('get', 'VB'),
#   ('quickly', 'RB'),
#   ('try', 'VB'),
#   ('buy', 'NN'),
#   ('withread', 'NN')],
#  [('value', 'NN'),
#   ('moneyits', 'VBZ'),
#   ('awesome', 'VBP'),
#   ('mobile', 'IN'),
#   ('phone', 'NN'),
#   ('world', 'NN'),
#   ('display', 'NN'),
#   ('good', 'JJ'),
#   ('bright', 'JJ'),
#   ('trust', 'NN'),
#   ('freinds', 'NNS'),
#   ('r', 'VBP'),
#   ('never', 'RB'),
#   ('regret', 'VB'),
#   ('buyingjust', 'NN'),
#   ('go', 'VB'),
#   ('iti', 'JJ'),
#   ('love', 'NN'),
#   ('phone', 'NN'),
#   ('switch', 'VB'),
#   ('iphone', 'NN'),
#   ('x', 'CD'),
#   ('read', 'NN')],
#  [('first', 'RB'),
#   ('io', 'JJ'),
#   ('phone', 'NN'),
#   ('happy', 'JJ'),
#   ('product', 'NN'),
#   ('much', 'RB'),
#   ('satisfied', 'JJ'),
#   ('love', 'NN'),
#   ('phoneread', 'NN')],
#  [('review', 'VB'),
#   ('month', 'NN'),
#   ('usagedoesnt', 'JJ'),
#   ('seem', 'VBP'),
#   ('bulky', 'JJ'),
#   ('decent', 'JJ'),
#   ('touch', 'NN'),
#   ('camera', 'NN'),
#   ('standard', 'NN'),
#   ('maintained', 'VBD'),
#   ('quality', 'NN'),
#   ('iphone', 'NN'),
#   ('go', 'VBP'),
#   ('budget', 'NN'),
#   ('enough', 'JJ'),
#   ('pro', 'JJ'),
#   ('model', 'FW'),
#   ('value', 'NN'),
#   ('money', 'NN'),
#   ('among', 'IN'),
#   ('series', 'NN'),
#   ('stereo', 'NN'),
#   ('speaker', 'NN'),
#   ('good', 'JJ'),
#   ('love', 'NN'),
#   ('stereo', 'NN'),
#   ('sound', 'NN'),
#   ('battery', 'NN'),
#   ('backup', 'NN'),
#   ('decent', 'NN'),
#   ('still', 'RB'),
#   ('better', 'RBR'),
#   ('iphone', 'NN'),
#   ('processor', 'NN'),
#   ('fast', 'RB'),
#   ('phone', 'NN'),
#   ('doesnt', 'NN'),
#   ('lag', 'NN'),
#   ('even', 'RB'),
#   ('heavy', 'JJ'),
#   ('game', 'NN'),
#   ('waterproof', 'JJ'),
#   ('faster', 'RBR'),
#   ('face', 'NN'),
#   ('id', 'JJ'),
#   ('fingerprint', 'NN'),
#   ('scanner', 'NN'),
#   ('caread', 'NN')],
#  [('best', 'JJS'),
#   ('budget', 'NN'),
#   ('iphone', 'NN'),
#   ('till', 'NN'),
#   ('date', 'NN'),
#   ('go', 'VBP'),
#   ('guy', 'NN'),
#   ('without', 'IN'),
#   ('second', 'JJ'),
#   ('thought', 'JJ'),
#   ('let', 'NN'),
#   ('explain', 'VB'),
#   ('guy', 'JJ'),
#   ('camera', 'NN'),
#   ('display', 'NN'),
#   ('battery', 'NN'),
#   ('performance', 'NN'),
#   ('camera', 'NN'),
#   ('price', 'NN'),
#   ('range', 'NN'),
#   ('comparison', 'NN'),
#   ('camera', 'NN'),
#   ('youll', 'NN'),
#   ('love', 'NN'),
#   ('picture', 'NN'),
#   ('quality', 'NN'),
#   ('well', 'RB'),
#   ('video', 'JJ'),
#   ('quality', 'NN'),
#   ('vlogger', 'NN'),
#   ('wanted', 'VBD'),
#   ('iphone', 'NN'),
#   ('k', 'NN'),
#   ('video', 'NN'),
#   ('front', 'JJ'),
#   ('camera', 'NN'),
#   ('got', 'VBD'),
#   ('phone', 'NN'),
#   ('happy', 'JJ'),
#   ('battery', 'NN'),
#   ('use', 'NN'),
#   ('phone', 'NN'),
#   ('roughly', 'RB'),
#   ('active', 'JJ'),
#   ('social', 'JJ'),
#   ('medium', 'NN'),
#   ('person', 'NN'),
#   ('youtube', 'JJ'),
#   ('channel', 'NN'),
#   ('battery', 'NN'),
#   ('baread', 'NN')],
#  [('almost', 'RB'),
#   ('month', 'NN'),
#   ('since', 'IN'),
#   ('using', 'VBG'),
#   ('phone', 'NN'),
#   ('upgraded', 'VBD'),
#   ('iphone', 'NN'),
#   ('main', 'JJ'),
#   ('issue', 'NN'),
#   ('battery', 'NN'),
#   ('phone', 'NN'),
#   ('awesome', 'JJ'),
#   ('come', 'VBN'),
#   ('battery', 'NN'),
#   ('last', 'JJ'),
#   ('day', 'NN'),
#   ('half', 'VBD'),
#   ('regular', 'JJ'),
#   ('use', 'NN'),
#   ('internet', 'NN'),
#   ('connected', 'VBN'),
#   ('always', 'RB'),
#   ('g', 'JJ'),
#   ('cant', 'JJ'),
#   ('move', 'NN'),
#   ('forward', 'RB'),
#   ('without', 'IN'),
#   ('saying', 'VBG'),
#   ('battery', 'NN'),
#   ('phone', 'NN'),
#   ('life', 'NN'),
#   ('saver', 'NN'),
#   ('traveling', 'VBG'),
#   ('work', 'NN'),
#   ('dont', 'NN'),
#   ('get', 'VB'),
#   ('option', 'NN'),
#   ('charge', 'NN'),
#   ('camera', 'NN'),
#   ('superb', 'NN'),
#   ('front', 'JJ'),
#   ('cam', 'NN'),
#   ('selfies', 'NNS'),
#   ('back', 'RB'),
#   ('cam', 'VBP'),
#   ('photo', 'NN'),
#   ('awesome', 'JJ'),
#   ('read', 'NN')],
#  [('iphone', 'NN'),
#   ('awesome', 'JJ'),
#   ('battery', 'NN'),
#   ('backup', 'NN'),
#   ('nice', 'JJ'),
#   ('continuously', 'RB'),
#   ('hour', 'NN'),
#   ('use', 'NN'),
#   ('itcamera', 'NN'),
#   ('awesome', 'JJ'),
#   ('display', 'NN'),
#   ('fabi', 'NN'),
#   ('love', 'VBP'),
#   ('aloti', 'JJ'),
#   ('wait', 'NN'),
#   ('day', 'NN'),
#   ('pre', 'VB'),
#   ('ordered', 'VBN'),
#   ('itoveralll', 'JJ'),
#   ('worth', 'JJ'),
#   ('pricethese', 'JJ'),
#   ('image', 'NN'),
#   ('clicked', 'VBD'),
#   ('iphoneand', 'JJ'),
#   ('love', 'NN'),
#   ('itread', 'NN')],
#  [('excellent', 'JJ'),
#   ('camera', 'NN'),
#   ('good', 'JJ'),
#   ('performance', 'NN'),
#   ('lag', 'NN'),
#   ('lcd', 'NN'),
#   ('display', 'NN'),
#   ('also', 'RB'),
#   ('good', 'JJ'),
#   ('difference', 'NN'),
#   ('come', 'VBN'),
#   ('watch', 'NN'),
#   ('movie', 'NN'),
#   ('prime', 'JJ'),
#   ('netflix', 'RB'),
#   ('colour', 'VBP'),
#   ('vibrant', 'JJ'),
#   ('see', 'NN'),
#   ('amoled', 'VBD'),
#   ('display', 'NN'),
#   ('charger', 'NN'),
#   ('box', 'NN'),
#   ('watt', 'NNS'),
#   ('take', 'VBP'),
#   ('hour', 'NN'),
#   ('charge', 'NN'),
#   ('guy', 'NN'),
#   ('prepare', 'VB'),
#   ('buy', 'VB'),
#   ('watt', 'JJ'),
#   ('charger', 'NN'),
#   ('finally', 'RB'),
#   ('android', 'JJ'),
#   ('user', 'NN'),
#   ('first', 'RB'),
#   ('iapple', 'JJ'),
#   ('phone', 'NN'),
#   ('promise', 'NN'),
#   ('u', 'JJ'),
#   ('guy', 'NN'),
#   ('io', 'VB'),
#   ('smooth', 'JJ'),
#   ('overall', 'JJ'),
#   ('phone', 'NN'),
#   ('damn', 'RB'),
#   ('good', 'JJ'),
#   ('close', 'NN'),
#   ('eye', 'NN'),
#   ('buy', 'NN'),
#   ('thanks', 'NNS'),
#   ('tread', 'VBP')],
#  [('awesome', 'JJ'),
#   ('phone', 'NN'),
#   ('slightly', 'RB'),
#   ('high', 'JJ'),
#   ('price', 'NN'),
#   ('worth', 'IN'),
#   ('better', 'JJR'),
#   ('iphone', 'NN'),
#   ('xr', 'NN'),
#   ('camera', 'NN'),
#   ('superb', 'NN'),
#   ('wide', 'JJ'),
#   ('angle', 'NN'),
#   ('camera', 'NN'),
#   ('clear', 'JJ'),
#   ('mp', 'NN'),
#   ('selfie', 'NN'),
#   ('camera', 'NN'),
#   ('also', 'RB'),
#   ('good', 'JJ'),
#   ('chip', 'NN'),
#   ('give', 'VB'),
#   ('good', 'JJ'),
#   ('smooth', 'NNS'),
#   ('performanceread', 'VBP')],
#  [('really', 'RB'),
#   ('worth', 'JJ'),
#   ('money', 'NN'),
#   ('love', 'NN'),
#   ('best', 'RBS'),
#   ('phone', 'NN'),
#   ('everread', 'NN')],
#  [('migrated', 'VBN'),
#   ('op', 'JJ'),
#   ('pro', 'JJ'),
#   ('trust', 'NN'),
#   ('iphone', 'NN'),
#   ('totally', 'RB'),
#   ('worth', 'JJ'),
#   ('following', 'VBG'),
#   ('reasonsthere', 'JJ'),
#   ('absolutely', 'RB'),
#   ('issue', 'NN'),
#   ('display', 'NN'),
#   ('crisp', 'NN'),
#   ('sharp', 'JJ'),
#   ('found', 'VBD'),
#   ('much', 'RB'),
#   ('much', 'JJ'),
#   ('better', 'JJR'),
#   ('op', 'JJ'),
#   ('pro', 'JJ'),
#   ('netflix', 'FW'),
#   ('prime', 'JJ'),
#   ('video', 'NN'),
#   ('run', 'VB'),
#   ('crisply', 'RB'),
#   ('wont', 'JJ'),
#   ('miss', 'JJ'),
#   ('thing', 'NN'),
#   ('true', 'JJ'),
#   ('tone', 'NN'),
#   ('work', 'NN'),
#   ('flawlesslythe', 'NN'),
#   ('display', 'NN'),
#   ('brightness', 'NN'),
#   ('perfect', 'JJ'),
#   ('op', 'NN'),
#   ('calibrated', 'VBD'),
#   ('screen', 'JJ'),
#   ('properly', 'RB'),
#   ('iphone', 'NN'),
#   ('series', 'NN'),
#   ('really', 'RB'),
#   ('good', 'JJ'),
#   ('camera', 'NN'),
#   ('others', 'NNS'),
#   ('spoken', 'VBP'),
#   ('depth', 'JJ'),
#   ('batread', 'NN')],
#  [('first', 'RB'),
#   ('ever', 'RB'),
#   ('phone', 'NN'),
#   ('using', 'VBG'),
#   ('google', 'NN'),
#   ('nexus', 'NN'),
#   ('moving', 'VBG'),
#   ('android', 'JJ'),
#   ('io', 'JJ'),
#   ('great', 'JJ'),
#   ('experience', 'NN'),
#   ('worth', 'JJ'),
#   ('price', 'NN'),
#   ('highly', 'RB'),
#   ('recommend', 'JJ'),
#   ('want', 'VBP'),
#   ('move', 'NN'),
#   ('io', 'NN'),
#   ('best', 'JJS'),
#   ('part', 'NN'),
#   ('phone', 'NN'),
#   ('camera', 'NN'),
#   ('battery', 'NN'),
#   ('life', 'NN'),
#   ('two', 'CD'),
#   ('thing', 'NN'),
#   ('heart', 'NN'),
#   ('loved', 'VBD'),
#   ('happy', 'JJ'),
#   ('hand', 'NN'),
#   ('still', 'RB'),
#   ('exploring', 'VBG'),
#   ('feature', 'NN'),
#   ('cant', 'JJ'),
#   ('forget', 'NN'),
#   ('mention', 'NN'),
#   ('flipkart', 'NN'),
#   ('service', 'NN'),
#   ('prompt', 'JJ'),
#   ('service', 'NN'),
#   ('fast', 'RB'),
#   ('deliveryread', 'JJ')],
#  [('amazing', 'JJ'),
#   ('product', 'NN'),
#   ('apple', 'NN'),
#   ('camera', 'NN'),
#   ('simply', 'RB'),
#   ('superb', 'VBD'),
#   ('phone', 'NN'),
#   ('fasternight', 'NN'),
#   ('shot', 'NN'),
#   ('simply', 'RB'),
#   ('superb', 'JJ'),
#   ('detailing', 'VBG'),
#   ('colour', 'JJ'),
#   ('differentiation', 'NN'),
#   ('camera', 'NN'),
#   ('added', 'VBD'),
#   ('advantagethis', 'JJ'),
#   ('review', 'NN'),
#   ('written', 'VBN'),
#   ('iphone', 'JJ'),
#   ('glad', 'NNS'),
#   ('say', 'VBP'),
#   ('outsidecons', 'NNS'),
#   ('wise', 'VBP'),
#   ('see', 'VB'),
#   ('hd', 'JJ'),
#   ('display', 'VB'),
#   ('battery', 'NN'),
#   ('percentage', 'NN'),
#   ('indicator', 'NN'),
#   ('older', 'JJR'),
#   ('iphone', 'NN'),
#   ('assistive', 'JJ'),
#   ('touch', 'NN'),
#   ('control', 'NN'),
#   ('button', 'NN'),
#   ('itno', 'NN'),
#   ('oleophobic', 'IN'),
#   ('coating', 'VBG'),
#   ('back', 'RP'),
#   ('panel', 'NN'),
#   ('glass', 'NN'),
#   ('finger', 'NN'),
#   ('print', 'NN'),
#   ('visible', 'JJ'),
#   ('since', 'IN'),
#   ('bought', 'VBN'),
#   ('mint', 'NN'),
#   ('grread', 'NN')],
#  [('superb', 'JJ'),
#   ('product', 'NN'),
#   ('big', 'JJ'),
#   ('worthy', 'JJ'),
#   ('upgrade', 'NN'),
#   ('mi', 'NN'),
#   ('iphone', 'NN'),
#   ('totally', 'RB'),
#   ('loved', 'VBD'),
#   ('read', 'NN')],
#  [('upgraded', 'JJ'),
#   ('iphone', 'NN'),
#   ('best', 'JJS'),
#   ('phone', 'NN'),
#   ('iphone', 'NN'),
#   ('user', 'NN'),
#   ('battery', 'NN'),
#   ('much', 'RB'),
#   ('better', 'JJR'),
#   ('iphones', 'NNS'),
#   ('camera', 'VBP'),
#   ('awesome', 'JJ'),
#   ('love', 'NN'),
#   ('use', 'NN'),
#   ('itcamera', 'NN'),
#   ('clear', 'JJ'),
#   ('nightread', 'NN')],
#  [('help', 'NN'),
#   ('see', 'VB'),
#   ('planning', 'VBG'),
#   ('buy', 'VB'),
#   ('iphone', 'JJ'),
#   ('say', 'VBP'),
#   ('yes', 'UH'),
#   ('plan', 'NN'),
#   ('want', 'VBP'),
#   ('disclose', 'VB'),
#   ('buy', 'VB'),
#   ('existing', 'VBG'),
#   ('iphone', 'NN'),
#   ('xxsxs', 'NNP'),
#   ('max', 'NN'),
#   ('xr', 'NNP'),
#   ('user', 'RB'),
#   ('better', 'RB'),
#   ('guy', 'NN'),
#   ('think', 'VBP'),
#   ('buy', 'VB'),
#   ('guy', 'NN'),
#   ('le', 'NN'),
#   ('better', 'RBR'),
#   ('gadget', 'NN'),
#   ('android', 'JJ'),
#   ('user', 'NN'),
#   ('planning', 'NN'),
#   ('buy', 'VB'),
#   ('premium', 'JJ'),
#   ('phone', 'NN'),
#   ('suggest', 'NN'),
#   ('please', 'NN'),
#   ('buy', 'VB'),
#   ('iphone', 'NN'),
#   ('instead', 'RB'),
#   ('buying', 'VBG'),
#   ('android', 'JJ'),
#   ('bet', 'NN'),
#   ('never', 'RB'),
#   ('go', 'VBP'),
#   ('back', 'RB'),
#   ('android', 'RB'),
#   ('using', 'VBG'),
#   ('io', 'NN'),
#   ('want', 'VBP'),
#   ('sharread', 'NN')],
#  [('well', 'RB'),
#   ('know', 'VB'),
#   ('specification', 'NN'),
#   ('one', 'CD'),
#   ('kind', 'NN'),
#   ('best', 'RBS'),
#   ('iphone', 'NN'),
#   ('till', 'NN'),
#   ('date', 'NN'),
#   ('many', 'JJ'),
#   ('enhancement', 'JJ'),
#   ('camera', 'NN'),
#   ('app', 'VBD'),
#   ('many', 'JJ'),
#   ('option', 'NN'),
#   ('love', 'IN'),
#   ('glass', 'NN'),
#   ('body', 'NN'),
#   ('matte', 'JJ'),
#   ('finish', 'JJ'),
#   ('lens', 'NNS'),
#   ('area', 'NN'),
#   ('back', 'RB'),
#   ('lovely', 'RB'),
#   ('colour', 'VBP'),
#   ('choose', 'JJ'),
#   ('best', 'RBS'),
#   ('battery', 'NN'),
#   ('iphone', 'NN'),
#   ('till', 'NN'),
#   ('date', 'NN'),
#   ('enough', 'JJ'),
#   ('last', 'JJ'),
#   ('day', 'NN'),
#   ('normal', 'JJ'),
#   ('usage', 'NN'),
#   ('tested', 'VBD'),
#   ('iphone', 'JJ'),
#   ('battery', 'NN'),
#   ('lasted', 'VBD'),
#   ('hour', 'NN'),
#   ('full', 'JJ'),
#   ('charge', 'NN'),
#   ('still', 'RB'),
#   ('battery', 'RB'),
#   ('charge', 'NN'),
#   ('left', 'VBD'),
#   ('watched', 'JJ'),
#   ('movie', 'NN'),
#   ('time', 'NN'),
#   ('normal', 'JJ'),
#   ('usage', 'NN'),
#   ('call', 'NN'),
#   ('browsing', 'NN'),
#   ('musiread', 'NN')],
#  [('built', 'VBN'),
#   ('quality', 'NN'),
#   ('premium', 'NN'),
#   ('battery', 'NN'),
#   ('back', 'RB'),
#   ('great', 'JJ'),
#   ('lcd', 'JJ'),
#   ('panel', 'NN'),
#   ('sharp', 'JJ'),
#   ('brightness', 'JJ'),
#   ('level', 'NN'),
#   ('high', 'JJ'),
#   ('camera', 'NN'),
#   ('super', 'NN'),
#   ('duper', 'IN'),
#   ('awesomethe', 'NN'),
#   ('red', 'JJ'),
#   ('colour', 'NN'),
#   ('people', 'NNS'),
#   ('think', 'VBP'),
#   ('bright', 'VBN'),
#   ('actually', 'RB'),
#   ('soothing', 'VBG'),
#   ('excellent', 'JJ'),
#   ('colour', 'NN'),
#   ('choose', 'NN'),
#   ('bionic', 'JJ'),
#   ('chip', 'NN'),
#   ('really', 'RB'),
#   ('flagship', 'JJ'),
#   ('processor', 'NN'),
#   ('beat', 'VBP'),
#   ('phone', 'NN'),
#   ('even', 'RB'),
#   ('gb', 'VBD'),
#   ('ram', 'JJ'),
#   ('camera', 'NN'),
#   ('module', 'NN'),
#   ('great', 'JJ'),
#   ('look', 'NN'),
#   ('stylishread', 'NN')],
#  [('really', 'RB'),
#   ('good', 'JJ'),
#   ('actually', 'RB'),
#   ('first', 'JJ'),
#   ('apple', 'NN'),
#   ('product', 'NN'),
#   ('using', 'VBG'),
#   ('really', 'RB'),
#   ('awesome', 'JJ'),
#   ('performance', 'NN'),
#   ('wise', 'NN'),
#   ('excellent', 'JJ'),
#   ('really', 'RB'),
#   ('happy', 'JJ'),
#   ('iphoneread', 'NN')],
#  [('good', 'JJ'),
#   ('performance', 'NN'),
#   ('camera', 'NN'),
#   ('best', 'JJS'),
#   ('like', 'IN'),
#   ('smooth', 'DT'),
#   ('response', 'NN'),
#   ('even', 'RB'),
#   ('water', 'NN'),
#   ('dont', 'JJ'),
#   ('buy', 'NN'),
#   ('mini', 'NNP'),
#   ('buy', 'NN'),
#   ('iphone', 'NN'),
#   ('far', 'RB'),
#   ('better', 'RBR'),
#   ('mini', 'JJ'),
#   ('believe', 'JJ'),
#   ('nice', 'JJ'),
#   ('day', 'NN'),
#   ('read', 'VB')],
#  [('reviewing', 'VBG'),
#   ('month', 'NN'),
#   ('beginning', 'VBG'),
#   ('battery', 'NN'),
#   ('performance', 'NN'),
#   ('good', 'NN'),
#   ('degraded', 'VBD'),
#   ('soon', 'RB'),
#   ('also', 'RB'),
#   ('facing', 'VBG'),
#   ('heating', 'VBG'),
#   ('issue', 'NN'),
#   ('mobile', 'RB'),
#   ('heat', 'NN'),
#   ('like', 'IN'),
#   ('stove', 'NN'),
#   ('sometimes', 'RB'),
#   ('can', 'MD'),
#   ('not', 'RB'),
#   ('even', 'RB'),
#   ('play', 'VB'),
#   ('pubg', 'RB'),
#   ('even', 'RB'),
#   ('low', 'JJ'),
#   ('setting', 'VBG'),
#   ('properly', 'JJ'),
#   ('performance', 'NN'),
#   ('problem', 'NN'),
#   ('heating', 'NN'),
#   ('also', 'RB'),
#   ('play', 'VBP'),
#   ('game', 'NN'),
#   ('min', 'NN'),
#   ('brightness', 'NN'),
#   ('automatically', 'RB'),
#   ('due', 'JJ'),
#   ('heating', 'VBG'),
#   ('even', 'RB'),
#   ('auto', 'NN'),
#   ('brightness', 'NN'),
#   ('set', 'VBN'),
#   ('solved', 'VBD'),
#   ('even', 'RB'),
#   ('u', 'JJ'),
#   ('manually', 'RB'),
#   ('increase', 'VBP'),
#   ('briread', 'NN')],
#  [('say', 'VB'),
#   ('im', 'NN'),
#   ('damn', 'NN'),
#   ('impressed', 'JJ'),
#   ('iphone', 'NN'),
#   ('say', 'VBP'),
#   ('iphone', 'NN'),
#   ('toughest', 'NN'),
#   ('glass', 'NN'),
#   ('ever', 'RB'),
#   ('smartphone', 'RB'),
#   ('youll', 'JJ'),
#   ('find', 'VBP'),
#   ('front', 'JJ'),
#   ('back', 'RB'),
#   ('totally', 'RB'),
#   ('smooth', 'JJ'),
#   ('fit', 'JJ'),
#   ('finish', 'JJ'),
#   ('full', 'JJ'),
#   ('apple', 'NN'),
#   ('quality', 'NN'),
#   ('there', 'RB'),
#   ('sense', 'VBZ'),
#   ('cheaping', 'NN'),
#   ('happened', 'VBD'),
#   ('construction', 'NN'),
#   ('without', 'IN'),
#   ('saying', 'VBG'),
#   ('camera', 'NN'),
#   ('feature', 'NN'),
#   ('review', 'NN'),
#   ('wont', 'VBD'),
#   ('complete', 'JJ'),
#   ('iphone', 'NN'),
#   ('dual', 'JJ'),
#   ('camera', 'NN'),
#   ('system', 'NN'),
#   ('consisting', 'VBG'),
#   ('wide', 'JJ'),
#   ('angle', 'NN'),
#   ('lens', 'VBZ'),
#   ('thats', 'NNS'),
#   ('pretty', 'RB'),
#   ('much', 'JJ'),
#   ('found', 'IN'),
#   ('iphone', 'NN'),
#   ('xr', 'NN'),
#   ('last', 'JJ'),
#   ('year', 'NN'),
#   ('butread', 'NN')],
#  [('first', 'JJ'),
#   ('time', 'NN'),
#   ('use', 'NN'),
#   ('io', 'NN'),
#   ('phone', 'NN'),
#   ('loving', 'VBG'),
#   ('upgradation', 'NN'),
#   ('love', 'IN'),
#   ('color', 'NN'),
#   ('love', 'NN'),
#   ('assebility', 'NN'),
#   ('phonei', 'VBP'),
#   ('need', 'NN'),
#   ('learn', 'VBP'),
#   ('functionality', 'NN'),
#   ('far', 'RB'),
#   ('seen', 'VBN'),
#   ('quite', 'RB'),
#   ('easy', 'JJ'),
#   ('lot', 'NN'),
#   ('function', 'NN'),
#   ('work', 'NN'),
#   ('specially', 'RB'),
#   ('content', 'JJ'),
#   ('writer', 'NN'),
#   ('blogger', 'NN'),
#   ('get', 'VB'),
#   ('lot', 'NN'),
#   ('content', 'JJ'),
#   ('creation', 'NN'),
#   ('platform', 'NN'),
#   ('really', 'RB'),
#   ('amazing', 'JJ'),
#   ('phone', 'NN'),
#   ('good', 'JJ'),
#   ('quality', 'NN'),
#   ('photography', 'NN'),
#   ('lot', 'NN'),
#   ('task', 'NN'),
#   ('tooread', 'NN')],
#  [('best', 'JJS'),
#   ('quality', 'NN'),
#   ('product', 'NN'),
#   ('iphone', 'NN'),
#   ('series', 'NN'),
#   ('sound', 'NN'),
#   ('quality', 'NN'),
#   ('camera', 'NN'),
#   ('quality', 'NN'),
#   ('awesome', 'VBP'),
#   ('battery', 'NN'),
#   ('life', 'NN'),
#   ('sufficient', 'JJ'),
#   ('hr', 'NN'),
#   ('backup', 'NN'),
#   ('full', 'JJ'),
#   ('internet', 'NN'),
#   ('access', 'NN'),
#   ('love', 'VB'),
#   ('product', 'NN'),
#   ('much', 'JJ'),
#   ('fast', 'RB'),
#   ('making', 'VBG'),
#   ('fast', 'JJ'),
#   ('daily', 'JJ'),
#   ('routine', 'NN'),
#   ('highlightscamera', 'NN'),
#   ('starvideo', 'NN'),
#   ('recording', 'VBG'),
#   ('starnight', 'JJ'),
#   ('mode', 'NN'),
#   ('shooting', 'VBG'),
#   ('camera', 'NN'),
#   ('star', 'NN'),
#   ('audio', 'JJ'),
#   ('quality', 'NN'),
#   ('awesome', 'JJ'),
#   ('battery', 'NN'),
#   ('star', 'NN'),
#   ('touch', 'JJ'),
#   ('star', 'NN'),
#   ('processor', 'NN'),
#   ('fast', 'RB'),
#   ('mread', 'NN')],
#  [('first', 'RB'),
#   ('thanks', 'NNS'),
#   ('flipkart', 'RB'),
#   ('amazing', 'VBG'),
#   ('deal', 'NN'),
#   ('phone', 'NN'),
#   ('outstanding', 'JJ'),
#   ('upgraded', 'VBD'),
#   ('iphone', 'NN'),
#   ('like', 'IN'),
#   ('big', 'JJ'),
#   ('upgrade', 'NN'),
#   ('packaging', 'NN'),
#   ('basic', 'JJ'),
#   ('expected', 'VBD'),
#   ('good', 'JJ'),
#   ('packaging', 'NN'),
#   ('wrapped', 'VBD'),
#   ('one', 'CD'),
#   ('layer', 'NN'),
#   ('bubble', 'JJ'),
#   ('wrap', 'NN'),
#   ('dont', 'NN'),
#   ('think', 'VBP'),
#   ('enough', 'IN'),
#   ('protect', 'NN'),
#   ('expensive', 'JJ'),
#   ('phone', 'NN'),
#   ('recommend', 'NN'),
#   ('phone', 'NN'),
#   ('seller', 'NN'),
#   ('well', 'RB'),
#   ('im', 'JJ'),
#   ('posting', 'VBG'),
#   ('review', 'NN'),
#   ('using', 'VBG'),
#   ('daysread', 'NN')],
#  [('directly', 'RB'),
#   ('switch', 'VB'),
#   ('iphone', 'NN'),
#   ('iphone', 'NN'),
#   ('best', 'JJS'),
#   ('premium', 'NN'),
#   ('smartphone', 'NN'),
#   ('recommend', 'VBP'),
#   ('everyone', 'NN'),
#   ('excellent', 'JJ'),
#   ('quality', 'NN'),
#   ('color', 'NN'),
#   ('iphone', 'NN'),
#   ('seriescamera', 'NN'),
#   ('quality', 'NN'),
#   ('awesome', 'VBP'),
#   ('major', 'JJ'),
#   ('feel', 'NN'),
#   ('hold', 'JJ'),
#   ('hand', 'NN'),
#   ('sound', 'JJ'),
#   ('quality', 'NN'),
#   ('volume', 'NN'),
#   ('also', 'RB'),
#   ('higher', 'RBR'),
#   ('previous', 'JJ'),
#   ('model', 'NN'),
#   ('recommend', 'VBP'),
#   ('buy', 'VB'),
#   ('iphone', 'JJ'),
#   ('instead', 'RB'),
#   ('pro', 'JJ'),
#   ('model', 'FW'),
#   ('nothing', 'NN'),
#   ('much', 'JJ'),
#   ('difference', 'NN'),
#   ('model', 'NN'),
#   ('contains', 'VBZ'),
#   ('everything', 'NN'),
#   ('fulfill', 'NN'),
#   ('need', 'VBP'),
#   ('one', 'CD'),
#   ('thing', 'NN'),
#   ('dislike', 'NN'),
#   ('aboread', 'NN')],
#  [('looking', 'VBG'),
#   ('good', 'JJ'),
#   ('super', 'JJ'),
#   ('stylish', 'NN'),
#   ('phone', 'NN'),
#   ('clean', 'JJ'),
#   ('box', 'NN'),
#   ('good', 'JJ'),
#   ('delivery', 'NN'),
#   ('fast', 'RB'),
#   ('delivery', 'NN'),
#   ('original', 'JJ'),
#   ('box', 'NN'),
#   ('original', 'JJ'),
#   ('iphone', 'NN'),
#   ('read', 'NN')],
#  [('battery', 'NN'),
#   ('backup', 'NN'),
#   ('extraordinary', 'JJ'),
#   ('camera', 'NN'),
#   ('decent', 'JJ'),
#   ('performance', 'NN'),
#   ('offered', 'VBD'),
#   ('bionic', 'JJ'),
#   ('awsome', 'JJ'),
#   ('display', 'NN'),
#   ('good', 'JJ'),
#   ('practical', 'JJ'),
#   ('usage', 'NN'),
#   ('like', 'IN'),
#   ('visibility', 'NN'),
#   ('display', 'VBP'),
#   ('good', 'JJ'),
#   ('direct', 'JJ'),
#   ('sun', 'NN'),
#   ('light', 'NN'),
#   ('compare', 'VBP'),
#   ('pro', 'JJ'),
#   ('model', 'FW'),
#   ('iam', 'NN'),
#   ('extremely', 'RB'),
#   ('satisfied', 'JJ'),
#   ('money', 'NN'),
#   ('spentread', 'NN')],
#  [('well', 'RB'),
#   ('switching', 'VBG'),
#   ('android', 'NN'),
#   ('io', 'NN'),
#   ('first', 'JJ'),
#   ('thing', 'NN'),
#   ('need', 'NN'),
#   ('careful', 'JJ'),
#   ('loose', 'JJ'),
#   ('whatsapp', 'NN'),
#   ('chat', 'WP'),
#   ('backup', 'VBZ'),
#   ('different', 'JJ'),
#   ('operating', 'VBG'),
#   ('system', 'NN'),
#   ('camera', 'NN'),
#   ('clarity', 'NN'),
#   ('awesome', 'VBP'),
#   ('though', 'IN'),
#   ('lcd', 'JJ'),
#   ('screen', 'NN'),
#   ('clarity', 'NN'),
#   ('resolution', 'NN'),
#   ('good', 'JJ'),
#   ('battery', 'NN'),
#   ('backup', 'NN'),
#   ('also', 'RB'),
#   ('good', 'JJ'),
#   ('unlike', 'IN'),
#   ('previous', 'JJ'),
#   ('gen', 'NN'),
#   ('iphone', 'NN'),
#   ('far', 'RB'),
#   ('experience', 'RB'),
#   ('good', 'JJ'),
#   ('padre', 'NNS'),
#   ('month', 'NN'),
#   ('usageps', 'JJ'),
#   ('black', 'JJ'),
#   ('dark', 'NN'),
#   ('grey', 'NN'),
#   ('shade', 'VBD'),
#   ('jet', 'NN'),
#   ('blackread', 'NN')],
#  [('love', 'VB'),
#   ('iphone', 'NN'),
#   ('great', 'JJ'),
#   ('performancecamera', 'NN'),
#   ('battery', 'NN'),
#   ('everything', 'NN'),
#   ('go', 'VBP'),
#   ('uncompareble', 'JJ'),
#   ('battery', 'NN'),
#   ('backup', 'NN'),
#   ('doubt', 'NN'),
#   ('iphone', 'NN'),
#   ('camera', 'NN'),
#   ('see', 'VBP'),
#   ('picture', 'NN'),
#   ('shot', 'NN'),
#   ('iphone', 'NN'),
#   ('love', 'NN'),
#   ('iphone', 'NN'),
#   ('great', 'JJ'),
#   ('performancecamera', 'NN'),
#   ('battery', 'NN'),
#   ('everything', 'NN'),
#   ('go', 'VBP'),
#   ('uncompareble', 'JJ'),
#   ('battery', 'NN'),
#   ('backup', 'NN'),
#   ('doubt', 'NN'),
#   ('iphone', 'NN'),
#   ('camera', 'NN'),
#   ('see', 'VBP'),
#   ('picture', 'NN'),
#   ('shot', 'NN'),
#   ('iphone', 'NN'),
#   ('love', 'NN'),
#   ('iphone', 'NN'),
#   ('great', 'JJ'),
#   ('performancecamera', 'NN'),
#   ('battery', 'NN'),
#   ('everything', 'NN'),
#   ('go', 'VBP'),
#   ('uncompareread', 'JJ')],
#  [('best', 'JJS'),
#   ('class', 'NN'),
#   ('battery', 'NN'),
#   ('backup', 'NN'),
#   ('good', 'JJ'),
#   ('especially', 'RB'),
#   ('play', 'VBP'),
#   ('game', 'NN'),
#   ('like', 'IN'),
#   ('pubg', 'NN'),
#   ('cod', 'NN'),
#   ('sort', 'NN'),
#   ('heavy', 'JJ'),
#   ('hold', 'NN'),
#   ('hand', 'NN'),
#   ('portrait', 'NN'),
#   ('mode', 'NN'),
#   ('best', 'JJS'),
#   ('click', 'JJ'),
#   ('picture', 'NN'),
#   ('stage', 'NN'),
#   ('light', 'JJ'),
#   ('effect', 'NN'),
#   ('awesome', 'JJ'),
#   ('try', 'NN'),
#   ('click', 'NN'),
#   ('photo', 'NN'),
#   ('outside', 'IN'),
#   ('nature', 'NN'),
#   ('photo', 'NN'),
#   ('inside', 'IN'),
#   ('home', 'NN'),
#   ('room', 'NN'),
#   ('give', 'VBP'),
#   ('quality', 'NN'),
#   ('phone', 'NN'),
#   ('even', 'RB'),
#   ('dslrread', 'VBD')],
#  [('excited', 'VBN'),
#   ('phone', 'NN'),
#   ('phone', 'NN'),
#   ('real', 'JJ'),
#   ('power', 'NN'),
#   ('unlike', 'IN'),
#   ('android', 'JJ'),
#   ('phone', 'NN'),
#   ('sd', 'NN'),
#   ('battery', 'NN'),
#   ('life', 'NN'),
#   ('good', 'JJ'),
#   ('camera', 'NN'),
#   ('quality', 'NN'),
#   ('excellent', 'NN'),
#   ('comapred', 'VBD'),
#   ('redmi', 'JJ'),
#   ('phone', 'NN'),
#   ('except', 'IN'),
#   ('google', 'NN'),
#   ('pixel', 'NN'),
#   ('enjoying', 'VBG'),
#   ('every', 'DT'),
#   ('single', 'JJ'),
#   ('bit', 'NN'),
#   ('would', 'MD'),
#   ('recommed', 'VB'),
#   ('budgetread', 'NN')],
#  [('awesome', 'JJ'),
#   ('product', 'NN'),
#   ('working', 'VBG'),
#   ('good', 'JJ'),
#   ('camera', 'NN'),
#   ('quality', 'NN'),
#   ('best', 'JJS'),
#   ('product', 'NN'),
#   ('also', 'RB'),
#   ('flipkart', 'RB'),
#   ('great', 'JJ'),
#   ('deal', 'NN'),
#   ('offer', 'NN'),
#   ('nice', 'JJ'),
#   ('priceread', 'NN')],
#  [('excellent', 'JJ'),
#   ('camera', 'NN'),
#   ('display', 'NN'),
#   ('touching', 'VBG'),
#   ('nice', 'JJ'),
#   ('smooth', 'JJ'),
#   ('improvement', 'NN'),
#   ('iphone', 'NN'),
#   ('xr', 'NNP'),
#   ('new', 'JJ'),
#   ('processor', 'NN'),
#   ('fastread', 'NN')],
#  [('month', 'NN'),
#   ('use', 'NN'),
#   ('found', 'VBD'),
#   ('camera', 'NN'),
#   ('quality', 'NN'),
#   ('best', 'RBS'),
#   ('compared', 'VBN'),
#   ('previous', 'JJ'),
#   ('samsung', 'NN'),
#   ('note', 'NN'),
#   ('display', 'NN'),
#   ('good', 'JJ'),
#   ('note', 'NN'),
#   ('also', 'RB'),
#   ('charging', 'VBG'),
#   ('slowapple', 'JJ'),
#   ('add', 'JJ'),
#   ('fast', 'RB'),
#   ('charger', 'NN'),
#   ('like', 'IN'),
#   ('plus', 'CC'),
#   ('probest', 'VB'),
#   ('phone', 'NN'),
#   ('daily', 'JJ'),
#   ('useread', 'NN')],
#  [('camera', 'NN'),
#   ('awesome', 'JJ'),
#   ('feel', 'NN'),
#   ('iphone', 'RB'),
#   ('awesome', 'RB'),
#   ('good', 'JJ'),
#   ('gaming', 'NN'),
#   ('also', 'RB'),
#   ('try', 'VB'),
#   ('pubg', 'NN'),
#   ('hd', 'NNS'),
#   ('wowread', 'VBP')],
#  [('awesome', 'JJ'),
#   ('purchase', 'NN'),
#   ('amazing', 'VBG'),
#   ('phone', 'NN'),
#   ('good', 'JJ'),
#   ('battery', 'NN'),
#   ('backup', 'NN'),
#   ('top', 'JJ'),
#   ('notch', 'NN'),
#   ('device', 'NN'),
#   ('white', 'JJ'),
#   ('colour', 'JJ'),
#   ('look', 'NN'),
#   ('amazing', 'VBG'),
#   ('phone', 'NN'),
#   ('extra', 'JJ'),
#   ('feature', 'NN'),
#   ('iphone', 'NN'),
#   ('xr', 'NNP'),
#   ('overall', 'JJ'),
#   ('value', 'NN'),
#   ('moneyread', 'NN')],
#  [('amazing', 'VBG'),
#   ('camera', 'NN'),
#   ('feel', 'NN'),
#   ('super', 'JJ'),
#   ('machine', 'NN'),
#   ('describe', 'NN'),
#   ('feeling', 'VBG'),
#   ('amazing', 'VBG'),
#   ('phone', 'NN'),
#   ('lucky', 'JJ'),
#   ('thisread', 'NN')],
#  [('awesome', 'JJ'),
#   ('phone', 'NN'),
#   ('got', 'VBD'),
#   ('many', 'JJ'),
#   ('smart', 'JJ'),
#   ('feature', 'NN'),
#   ('apart', 'RB'),
#   ('mind', 'IN'),
#   ('blowing', 'VBG'),
#   ('look', 'NN'),
#   ('camera', 'NN'),
#   ('display', 'NN'),
#   ('battery', 'NN'),
#   ('sound', 'NN'),
#   ('fallen', 'VBN'),
#   ('love', 'IN'),
#   ('phone', 'NN'),
#   ('must', 'MD'),
#   ('buy', 'VB'),
#   ('phone', 'NN'),
#   ('got', 'VBD'),
#   ('enough', 'JJ'),
#   ('money', 'NN'),
#   ('thanks', 'NNS'),
#   ('flipkart', 'VBP'),
#   ('apple', 'NN'),
#   ('courseread', 'NN')],
#  [('fabulous', 'JJ'),
#   ('mobile', 'JJ'),
#   ('look', 'NN'),
#   ('awesome', 'JJ'),
#   ('performance', 'NN'),
#   ('unbeaten', 'JJ'),
#   ('camera', 'NN'),
#   ('like', 'IN'),
#   ('dslr', 'JJ'),
#   ('battery', 'NN'),
#   ('good', 'JJ'),
#   ('think', 'NN'),
#   ('beast', 'IN'),
#   ('mobileread', 'NN')],
#  [('dear', 'JJ'),
#   ('friend', 'NN'),
#   ('want', 'VBP'),
#   ('share', 'NN'),
#   ('experience', 'NN'),
#   ('amazing', 'VBG'),
#   ('phone', 'NN'),
#   ('first', 'RB'),
#   ('iphone', 'RB'),
#   ('special', 'JJ'),
#   ('thing', 'NN'),
#   ('mobile', 'JJ'),
#   ('great', 'JJ'),
#   ('camera', 'NN'),
#   ('battery', 'NN'),
#   ('backup', 'NN'),
#   ('awesome', 'JJ'),
#   ('display', 'NN'),
#   ('mean', 'NN'),
#   ('everything', 'NN'),
#   ('perfectloved', 'VBD'),
#   ('read', 'JJ')],
#  [('high', 'JJ'),
#   ('performance', 'NN'),
#   ('devise', 'NN'),
#   ('like', 'IN'),
#   ('service', 'NN'),
#   ('flipkart', 'RB'),
#   ('delevary', 'JJ'),
#   ('fast', 'RB'),
#   ('packing', 'VBG'),
#   ('nice', 'JJ'),
#   ('perfect', 'JJ'),
#   ('phoneread', 'NN')],
#  [('amazing', 'VBG'),
#   ('phone', 'NN'),
#   ('great', 'JJ'),
#   ('deal', 'NN'),
#   ('received', 'VBD'),
#   ('super', 'JJR'),
#   ('fast', 'JJ'),
#   ('delivery', 'NN'),
#   ('flipkartread', 'NN')],
#  [('finally', 'RB'),
#   ('iphone', 'JJ'),
#   ('nice', 'JJ'),
#   ('battery', 'NN'),
#   ('backup', 'NN'),
#   ('update', 'JJ'),
#   ('iphone', 'NN'),
#   ('happy', 'JJ'),
#   ('camera', 'NN'),
#   ('mark', 'NN'),
#   ('low', 'JJ'),
#   ('light', 'NN'),
#   ('overall', 'RB'),
#   ('recommended', 'VBD'),
#   ('phone', 'NN'),
#   ('budget', 'NN'),
#   ('allows', 'VBZ'),
#   ('read', 'VB')],
#  [('really', 'RB'),
#   ('satisfied', 'JJ'),
#   ('product', 'NN'),
#   ('received', 'VBD'),
#   ('totally', 'RB'),
#   ('genuine', 'JJ'),
#   ('packaging', 'NN'),
#   ('also', 'RB'),
#   ('really', 'RB'),
#   ('good', 'JJ'),
#   ('ur', 'NN'),
#   ('planning', 'NN'),
#   ('buy', 'NN'),
#   ('go', 'VBP'),
#   ('itread', 'NN')],
#  [('worthy', 'JJ'),
#   ('buy', 'VB'),
#   ('much', 'JJ'),
#   ('happy', 'JJ'),
#   ('product', 'NN'),
#   ('thank', 'NN'),
#   ('u', 'JJ'),
#   ('flipkart', 'RB'),
#   ('received', 'VBD'),
#   ('item', 'NN'),
#   ('timeloved', 'VBN'),
#   ('itread', 'NN')],
#  [('great', 'JJ'),
#   ('iphonei', 'NN'),
#   ('writing', 'VBG'),
#   ('review', 'JJ'),
#   ('month', 'NN'),
#   ('usagecamera', 'JJ'),
#   ('excellent', 'NN'),
#   ('especially', 'RB'),
#   ('nightmodedisplay', 'JJ'),
#   ('perfectbattery', 'NN'),
#   ('backup', 'NN'),
#   ('awesomesound', 'IN'),
#   ('quality', 'NN'),
#   ('goodoverall', 'NN'),
#   ('apple', 'NN'),
#   ('give', 'VBP'),
#   ('perfect', 'JJ'),
#   ('iphone', 'NN'),
#   ('rangereally', 'RB'),
#   ('love', 'VB'),
#   ('iphone', 'NN'),
#   ('read', 'NN')],
#  [('im', 'NN'),
#   ('really', 'RB'),
#   ('happy', 'JJ'),
#   ('productdelivery', 'NN'),
#   ('fast', 'RB'),
#   ('wellit', 'JJ'),
#   ('gift', 'NN'),
#   ('sister', 'NN'),
#   ('loved', 'VBD'),
#   ('muchread', 'NN')],
#  [('great', 'JJ'),
#   ('iphone', 'NN'),
#   ('snappy', 'JJ'),
#   ('experience', 'NN'),
#   ('apple', 'NN'),
#   ('kind', 'NN'),
#   ('upgraded', 'VBD'),
#   ('iphone', 'NN'),
#   ('proscamera', 'NN'),
#   ('top', 'JJ'),
#   ('class', 'NN'),
#   ('battery', 'NN'),
#   ('top', 'NN'),
#   ('performed', 'VBD'),
#   ('chipset', 'JJ'),
#   ('need', 'NNS'),
#   ('say', 'VBP'),
#   ('apple', 'NN'),
#   ('kind', 'NN'),
#   ('security', 'NN'),
#   ('expect', 'VBP'),
#   ('apple', 'NN'),
#   ('display', 'NN'),
#   ('super', 'JJ'),
#   ('bright', 'NN'),
#   ('industry', 'NN'),
#   ('leading', 'VBG'),
#   ('colour', 'JJ'),
#   ('accuracy', 'NN'),
#   ('super', 'RBR'),
#   ('responsive', 'JJ'),
#   ('build', 'NN'),
#   ('quality', 'NN'),
#   ('expect', 'VBP'),
#   ('apple', 'NN'),
#   ('sturdy', 'JJ'),
#   ('premium', 'NN'),
#   ('durable', 'JJ'),
#   ('beautiful', 'JJ'),
#   ('stylish', 'JJ'),
#   ('o', 'NN'),
#   ('stable', 'JJ'),
#   ('o', 'JJ'),
#   ('smartphone', 'NN'),
#   ('industry', 'NN'),
#   ('con', 'NN'),
#   ('gdisplay', 'NN'),
#   ('based', 'VBN'),
#   ('oled', 'JJ'),
#   ('technology', 'NN'),
#   ('charger', 'NN'),
#   ('headphone', 'NN'),
#   ('apple', 'NN'),
#   ('sticread', 'NN')],
#  [('value', 'NN'),
#   ('money', 'NN'),
#   ('star', 'NN'),
#   ('rating', 'NN'),
#   ('excellent', 'JJ'),
#   ('camerabattery', 'NN'),
#   ('backup', 'NN'),
#   ('full', 'JJ'),
#   ('day', 'NN'),
#   ('single', 'JJ'),
#   ('chargetougher', 'NN'),
#   ('water', 'NN'),
#   ('resistant', 'JJ'),
#   ('design', 'NN'),
#   ('glossy', 'JJ'),
#   ('backthe', 'NN'),
#   ('screen', 'NN'),
#   ('excellent', 'JJ'),
#   ('brightness', 'NN'),
#   ('contrastapple', 'NN'),
#   ('bionic', 'JJ'),
#   ('fastest', 'JJS'),
#   ('smartphone', 'NN'),
#   ('chip', 'NN'),
#   ('planetexcellent', 'NN'),
#   ('battery', 'NN'),
#   ('life', 'NN'),
#   ('fast', 'RB'),
#   ('charging', 'VBG'),
#   ('supportstereo', 'NN'),
#   ('speaker', 'NN'),
#   ('great', 'JJ'),
#   ('qualityread', 'NN')],
#  [('always', 'RB'),
#   ('love', 'VB'),
#   ('apple', 'NN'),
#   ('product', 'NN'),
#   ('upgraded', 'VBD'),
#   ('old', 'JJ'),
#   ('iphone', 'NN'),
#   ('plus', 'CC'),
#   ('first', 'JJ'),
#   ('baby', 'NN'),
#   ('love', 'VB'),
#   ('click', 'NN'),
#   ('baby', 'NN'),
#   ('photo', 'NN'),
#   ('overall', 'JJ'),
#   ('love', 'NN'),
#   ('phone', 'NN'),
#   ('battery', 'NN'),
#   ('back', 'RB'),
#   ('okay', 'JJ'),
#   ('sound', 'NN'),
#   ('quality', 'NN'),
#   ('good', 'JJ'),
#   ('havent', 'NN'),
#   ('tested', 'VBN'),
#   ('yet', 'RB'),
#   ('waterproof', 'JJ'),
#   ('yet', 'RB'),
#   ('one', 'CD'),
#   ('thing', 'NN'),
#   ('hate', 'NN'),
#   ('apple', 'NN'),
#   ('could', 'MD'),
#   ('given', 'VBN'),
#   ('charger', 'VB'),
#   ('headphone', 'CD'),
#   ('boxread', 'NN')],
#  [('awesome', 'JJ'),
#   ('phone', 'NN'),
#   ('smooth', 'JJ'),
#   ('touch', 'RB'),
#   ('good', 'JJ'),
#   ('sexyy', 'NN'),
#   ('look', 'VB'),
#   ('one', 'CD'),
#   ('word', 'NN'),
#   ('awesomeread', 'NN')],
#  [('damn', 'NN'),
#   ('phone', 'NN'),
#   ('blast', 'NN'),
#   ('upgraded', 'VBD'),
#   ('android', 'JJ'),
#   ('io', 'JJ'),
#   ('duperb', 'NN'),
#   ('experience', 'NN'),
#   ('battery', 'NN'),
#   ('backup', 'NN'),
#   ('top', 'JJ'),
#   ('notch', 'NN'),
#   ('display', 'NN'),
#   ('also', 'RB'),
#   ('pretty', 'RB'),
#   ('goodread', 'JJ')],
#  [('rate', 'NN'),
#   ('product', 'NN'),
#   ('got', 'VBD'),
#   ('amazing', 'JJ'),
#   ('user', 'JJ'),
#   ('experience', 'NN'),
#   ('best', 'JJS'),
#   ('performing', 'VBG'),
#   ('bionic', 'JJ'),
#   ('processor', 'NN'),
#   ('screen', 'NN'),
#   ('responds', 'VBZ'),
#   ('graphic', 'JJ'),
#   ('rendering', 'VBG'),
#   ('top', 'JJ'),
#   ('notch', 'NN'),
#   ('casual', 'JJ'),
#   ('gaming', 'NN'),
#   ('internet', 'NN'),
#   ('browsing', 'VBG'),
#   ('battery', 'NN'),
#   ('last', 'JJ'),
#   ('approx', 'JJ'),
#   ('day', 'NN'),
#   ('camera', 'NN'),
#   ('good', 'JJ'),
#   ('fall', 'NN'),
#   ('love', 'VBP'),
#   ('portrait', 'NN'),
#   ('mode', 'NN'),
#   ('call', 'NN'),
#   ('loyal', 'NN'),
#   ('apple', 'NN'),
#   ('customer', 'NN'),
#   ('whatever', 'WDT'),
#   ('wont', 'JJ'),
#   ('stop', 'NN'),
#   ('praising', 'VBG'),
#   ('product', 'NN'),
#   ('overall', 'JJ'),
#   ('experience', 'NN'),
#   ('user', 'NN'),
#   ('experience', 'NN'),
#   ('matter', 'NN'),
#   ('worth', 'NN'),
#   ('every', 'DT'),
#   ('penny', 'NN'),
#   ('paybelow', 'NN'),
#   ('arread', 'NN')],
#  [('purchased', 'VBN'),
#   ('iphone', 'JJ'),
#   ('month', 'NN'),
#   ('back', 'RB'),
#   ('must', 'MD'),
#   ('say', 'VB'),
#   ('apple', 'NN'),
#   ('impressed', 'JJ'),
#   ('yet', 'RB'),
#   ('apple', 'NN'),
#   ('user', 'NN'),
#   ('past', 'IN'),
#   ('year', 'NN'),
#   ('phone', 'NN'),
#   ('power', 'NN'),
#   ('packed', 'VBD'),
#   ('amazing', 'JJ'),
#   ('feature', 'NN'),
#   ('impressed', 'JJ'),
#   ('battery', 'NN'),
#   ('backup', 'NN'),
#   ('phone', 'NN'),
#   ('offer', 'NN'),
#   ('battery', 'NN'),
#   ('easily', 'RB'),
#   ('run', 'VB'),
#   ('upto', 'JJ'),
#   ('day', 'NN'),
#   ('single', 'JJ'),
#   ('charge', 'NN'),
#   ('moderate', 'JJ'),
#   ('toheavy', 'JJ'),
#   ('usage', 'NN'),
#   ('youre', 'NN'),
#   ('looking', 'VBG'),
#   ('value', 'NN'),
#   ('money', 'NN'),
#   ('device', 'NN'),
#   ('dont', 'NN'),
#   ('see', 'VBP'),
#   ('phone', 'NN'),
#   ('price', 'NN'),
#   ('range', 'NN'),
#   ('match', 'NN'),
#   ('iphone', 'NN'),
#   ('one', 'CD'),
#   ('thing', 'NN'),
#   ('didnt', 'NN'),
#   ('like', 'IN'),
#   ('read', 'NN')],
#  [('im', 'NN'),
#   ('switching', 'VBG'),
#   ('phone', 'NN'),
#   ('oppo', 'NN'),
#   ('reno', 'NN'),
#   ('x', 'NNP'),
#   ('zoomits', 'VBZ'),
#   ('really', 'RB'),
#   ('impressiverarely', 'JJ'),
#   ('im', 'NN'),
#   ('missing', 'VBG'),
#   ('smooth', 'JJ'),
#   ('display', 'NN'),
#   ('touch', 'JJ'),
#   ('response', 'NN'),
#   ('like', 'IN'),
#   ('oppo', 'JJ'),
#   ('reno', 'NN'),
#   ('buti', 'NN'),
#   ('really', 'RB'),
#   ('loved', 'VBD'),
#   ('itcamera', 'NN'),
#   ('really', 'RB'),
#   ('impressiveread', 'JJ')],
#  [('back', 'RB'),
#   ('apple', 'NN'),
#   ('iphone', 'NN'),
#   ('gap', 'NN'),
#   ('year', 'NN'),
#   ('pleasure', 'NN'),
#   ('use', 'NN'),
#   ('io', 'JJ'),
#   ('quality', 'NN'),
#   ('product', 'NN'),
#   ('apple', 'NN'),
#   ('iphone', 'NN'),
#   ('still', 'RB'),
#   ('work', 'VBP'),
#   ('like', 'IN'),
#   ('beast', 'NN'),
#   ('also', 'RB'),
#   ('really', 'RB'),
#   ('capable', 'JJ'),
#   ('day', 'NN'),
#   ('day', 'NN'),
#   ('usage', 'VB'),
#   ('well', 'RB'),
#   ('hard', 'RB'),
#   ('core', 'NN'),
#   ('gaming', 'NN'),
#   ('battery', 'NN'),
#   ('awesome', 'JJ'),
#   ('im', 'NN'),
#   ('really', 'RB'),
#   ('much', 'JJ'),
#   ('satisfied', 'JJ'),
#   ('apart', 'NN'),
#   ('fto', 'VBP'),
#   ('gorgious', 'JJ'),
#   ('ip', 'NN'),
#   ('lcd', 'NN'),
#   ('amoled', 'VBD'),
#   ('better', 'JJR'),
#   ('everything', 'NN'),
#   ('mind', 'NN'),
#   ('boggling', 'VBG'),
#   ('iphoneread', 'NN')],
#  [('upgrade', 'JJ'),
#   ('plus', 'CC'),
#   ('iphone', 'JJ'),
#   ('ao', 'NN'),
#   ('far', 'RB'),
#   ('experience', 'RB'),
#   ('well', 'RB'),
#   ('good', 'JJ'),
#   ('felt', 'VBD'),
#   ('smoother', 'JJ'),
#   ('plus', 'CC'),
#   ('camera', 'JJ'),
#   ('quality', 'NN'),
#   ('superb', 'NN'),
#   ('battery', 'NN'),
#   ('backup', 'NN'),
#   ('descent', 'NN'),
#   ('heavy', 'JJ'),
#   ('user', 'NN'),
#   ('get', 'VB'),
#   ('power', 'NN'),
#   ('day', 'NN'),
#   ('go', 'VBP'),
#   ('need', 'MD'),
#   ('alrounder', 'VB'),
#   ('iphone', 'NN'),
#   ('competitve', 'NN'),
#   ('priceread', 'NN')],
#  [('best', 'JJS'),
#   ('apple', 'NN'),
#   ('iphone', 'NN'),
#   ('bought', 'VBD'),
#   ('reasonable', 'JJ'),
#   ('price', 'NN'),
#   ('camera', 'NN'),
#   ('quality', 'NN'),
#   ('next', 'IN'),
#   ('level', 'NN'),
#   ('awesome', 'JJ'),
#   ('n', 'RB'),
#   ('superior', 'JJ'),
#   ('quality', 'NN'),
#   ('android', 'VBP'),
#   ('phone', 'NN'),
#   ('even', 'RB'),
#   ('closerip', 'VBZ'),
#   ('also', 'RB'),
#   ('battery', 'NN'),
#   ('really', 'RB'),
#   ('good', 'JJ'),
#   ('packaging', 'NN'),
#   ('flipkart', 'NN'),
#   ('iphone', 'NN'),
#   ('poor', 'JJ'),
#   ('expensive', 'JJ'),
#   ('product', 'NN'),
#   ('firstly', 'RB'),
#   ('im', 'JJ'),
#   ('bit', 'NN'),
#   ('worried', 'JJ'),
#   ('quality', 'NN'),
#   ('product', 'NN'),
#   ('purchased', 'VBN'),
#   ('online', 'JJ'),
#   ('product', 'NN'),
#   ('think', 'NN'),
#   ('mine', 'NN'),
#   ('best', 'JJS'),
#   ('decision', 'NN'),
#   ('bought', 'VBD'),
#   ('flipkart', 'JJ'),
#   ('online', 'NN'),
#   ('got', 'VBD'),
#   ('genuine', 'JJ'),
#   ('appleread', 'NN')],
#  [('absolutely', 'RB'),
#   ('powerful', 'JJ'),
#   ('gadget', 'NNS'),
#   ('loved', 'VBD'),
#   ('look', 'NN'),
#   ('soo', 'JJ'),
#   ('glassy', 'JJ'),
#   ('classy', 'NN'),
#   ('would', 'MD'),
#   ('definitely', 'RB'),
#   ('recommend', 'VB'),
#   ('model', 'NN'),
#   ('apple', 'NN'),
#   ('disappointed', 'JJ'),
#   ('w', 'NN'),
#   ('charger', 'NN'),
#   ('one', 'CD'),
#   ('purchase', 'NN'),
#   ('w', 'NN'),
#   ('adapter', 'NN'),
#   ('fast', 'VBD'),
#   ('charging', 'VBG'),
#   ('though', 'IN'),
#   ('battery', 'NN'),
#   ('backup', 'NN'),
#   ('great', 'JJ'),
#   ('bought', 'VBD'),
#   ('september', 'JJ'),
#   ('reviewing', 'VBG'),
#   ('long', 'JJ'),
#   ('im', 'NN'),
#   ('gon', 'NN'),
#   ('na', 'TO'),
#   ('put', 'VB'),
#   ('genuine', 'JJ'),
#   ('review', 'NN'),
#   ('hereread', 'NN')],
#  [('torn', 'JJ'),
#   ('oneplus', 'JJ'),
#   ('pro', 'FW'),
#   ('iphone', 'NN'),
#   ('shell', 'NN'),
#   ('extra', 'JJ'),
#   ('money', 'NN'),
#   ('say', 'VBP'),
#   ('afford', 'NN'),
#   ('truely', 'RB'),
#   ('best', 'JJS'),
#   ('package', 'NN'),
#   ('mind', 'NN'),
#   ('blowing', 'VBG'),
#   ('camera', 'NN'),
#   ('battery', 'NN'),
#   ('overall', 'JJ'),
#   ('performance', 'NN'),
#   ('face', 'NN'),
#   ('id', 'JJ'),
#   ('work', 'NN'),
#   ('like', 'IN'),
#   ('magic', 'JJ'),
#   ('even', 'RB'),
#   ('complete', 'JJ'),
#   ('darkness', 'NN'),
#   ('without', 'IN'),
#   ('firing', 'VBG'),
#   ('screen', 'JJ'),
#   ('brightness', 'NN'),
#   ('phone', 'NN'),
#   ('display', 'NN'),
#   ('fingerprint', 'NN'),
#   ('scanner', 'NN'),
#   ('night', 'NN'),
#   ('time', 'NN'),
#   ('really', 'RB'),
#   ('burn', 'VB'),
#   ('eye', 'NN'),
#   ('wanted', 'VBD'),
#   ('oneplus', 'JJ'),
#   ('display', 'NN'),
#   ('tbh', 'NN'),
#   ('oled', 'VBD'),
#   ('oneplus', 'CC'),
#   ('really', 'RB'),
#   ('bad', 'JJ'),
#   ('flickread', 'NN')],
#  [('use', 'NN'),
#   ('note', 'NN'),
#   ('using', 'VBG'),
#   ('io', 'JJ'),
#   ('android', 'JJ'),
#   ('devicescamera', 'NN'),
#   ('really', 'RB'),
#   ('good', 'JJ'),
#   ('feature', 'NN'),
#   ('portrait', 'NN'),
#   ('super', 'VBD'),
#   ('good', 'JJ'),
#   ('better', 'RBR'),
#   ('samsung', 'JJ'),
#   ('flagship', 'NN'),
#   ('overall', 'JJ'),
#   ('camera', 'NN'),
#   ('setup', 'NN'),
#   ('still', 'RB'),
#   ('enhanced', 'VBD'),
#   ('hopeful', 'JJ'),
#   ('better', 'JJR'),
#   ('upgrade', 'NN'),
#   ('software', 'NN'),
#   ('next', 'JJ'),
#   ('release', 'NN'),
#   ('operating', 'VBG'),
#   ('system', 'NN'),
#   ('quite', 'RB'),
#   ('breeze', 'JJ'),
#   ('user', 'JJ'),
#   ('experience', 'NN'),
#   ('daily', 'JJ'),
#   ('usage', 'NN'),
#   ('high', 'JJ'),
#   ('compared', 'VBN'),
#   ('android', 'VBP'),
#   ('moved', 'VBN'),
#   ('io', 'JJ'),
#   ('swiftly', 'RB'),
#   ('day', 'NN'),
#   ('office', 'NN'),
#   ('work', 'NN'),
#   ('notebattery', 'RB'),
#   ('hold', 'VB'),
#   ('quite', 'RB'),
#   ('well', 'RB'),
#   ('hr', 'VB'),
#   ('call', 'NN'),
#   ('read', 'NN')],
#  [('phone', 'NN'),
#   ('completely', 'RB'),
#   ('good', 'JJ'),
#   ('far', 'RB'),
#   ('camera', 'NN'),
#   ('apple', 'NN'),
#   ('king', 'VBG'),
#   ('itand', 'NN'),
#   ('beast', 'NN'),
#   ('performance', 'NN'),
#   ('battery', 'NN'),
#   ('pretty', 'RB'),
#   ('good', 'JJ'),
#   ('tooread', 'NN')],
#  [('everything', 'NN'),
#   ('u', 'NNS'),
#   ('like', 'IN'),
#   ('u', 'JJ'),
#   ('use', 'NN'),
#   ('iphone', 'NN'),
#   ('simple', 'JJ'),
#   ('change', 'NN'),
#   ('many', 'JJ'),
#   ('lower', 'JJR'),
#   ('model', 'NN'),
#   ('nice', 'JJ'),
#   ('use', 'NN'),
#   ('little', 'JJ'),
#   ('heavy', 'JJ'),
#   ('compared', 'VBN'),
#   ('previous', 'JJ'),
#   ('model', 'NN'),
#   ('like', 'IN'),
#   ('read', 'NN')],
#  [('great', 'JJ'),
#   ('phone', 'NN'),
#   ('camera', 'NN'),
#   ('display', 'NN'),
#   ('everything', 'NN'),
#   ('best', 'JJS'),
#   ('pricebest', 'NN'),
#   ('camera', 'NN'),
#   ('best', 'JJS'),
#   ('performance', 'NN'),
#   ('think', 'VBP'),
#   ('everyone', 'NN'),
#   ('buy', 'VB'),
#   ('phone', 'NN'),
#   ('best', 'JJS'),
#   ('battery', 'NN'),
#   ('life', 'NN'),
#   ('far', 'RB'),
#   ('iphone', 'JJ'),
#   ('series', 'NN'),
#   ('used', 'VBN'),
#   ('earlier', 'RBR'),
#   ('happy', 'JJ'),
#   ('thanks', 'NNS'),
#   ('flipkartread', 'VBP')],
#  [('best', 'JJS'),
#   ('amazing', 'VBG'),
#   ('productphone', 'NN'),
#   ('look', 'NN'),
#   ('premium', 'NN'),
#   ('battary', 'NN'),
#   ('also', 'RB'),
#   ('good', 'JJ'),
#   ('expected', 'VBN'),
#   ('wide', 'JJ'),
#   ('angle', 'NN'),
#   ('camera', 'NN'),
#   ('addictive', 'JJ'),
#   ('io', 'NN'),
#   ('loverthen', 'NN'),
#   ('phone', 'NN'),
#   ('best', 'JJS'),
#   ('choice', 'NN'),
#   ('allread', 'NN')],
#  [('genuinely', 'RB'),
#   ('liked', 'VBD'),
#   ('one', 'CD'),
#   ('best', 'JJS'),
#   ('mobile', 'NN'),
#   ('phone', 'NN'),
#   ('used', 'VBN'),
#   ('sho', 'JJ'),
#   ('smooth', 'JJ'),
#   ('security', 'NN'),
#   ('astonishing', 'VBG'),
#   ('plus', 'CC'),
#   ('good', 'JJ'),
#   ('camera', 'NN'),
#   ('quality', 'NN'),
#   ('overall', 'JJ'),
#   ('win', 'NN'),
#   ('winread', 'NN')],
#  [('go', 'VB'),
#   ('phone', 'NN'),
#   ('really', 'RB'),
#   ('amazing', 'JJ'),
#   ('ordered', 'JJ'),
#   ('wife', 'NN'),
#   ('click', 'JJ'),
#   ('photo', 'NN'),
#   ('thing', 'NN'),
#   ('better', 'RBR'),
#   ('dslr', 'NN'),
#   ('oneplus', 'JJ'),
#   ('camera', 'NN'),
#   ('suck', 'NN'),
#   ('iphone', 'NN'),
#   ('really', 'RB'),
#   ('amazing', 'JJ'),
#   ('come', 'NN'),
#   ('camera', 'NN'),
#   ('worth', 'IN'),
#   ('spending', 'VBG'),
#   ('k', 'JJ'),
#   ('con', 'JJ'),
#   ('display', 'NN'),
#   ('lcd', 'NN'),
#   ('using', 'VBG'),
#   ('u', 'JJ'),
#   ('dont', 'NN'),
#   ('feel', 'NN'),
#   ('u', 'JJ'),
#   ('compare', 'NN'),
#   ('phone', 'NN'),
#   ('u', 'JJ'),
#   ('see', 'NN'),
#   ('difference', 'NN'),
#   ('quite', 'RB'),
#   ('easily', 'RB'),
#   ('changing', 'VBG'),
#   ('android', 'RP'),
#   ('iphone', 'JJ'),
#   ('bit', 'NN'),
#   ('difficult', 'JJ'),
#   ('coz', 'JJ'),
#   ('thing', 'NN'),
#   ('u', 'JJ'),
#   ('dont', 'NN'),
#   ('know', 'VBP'),
#   ('liked', 'VBN'),
#   ('aread', 'JJ')],
#  [('awesome', 'JJ'),
#   ('camera', 'NN'),
#   ('smooth', 'CC'),
#   ('fast', 'JJ'),
#   ('ui', 'JJ'),
#   ('display', 'NN'),
#   ('great', 'JJ'),
#   ('though', 'IN'),
#   ('led', 'JJ'),
#   ('black', 'JJ'),
#   ('area', 'NN'),
#   ('top', 'NN'),
#   ('could', 'MD'),
#   ('reduced', 'VB'),
#   ('battery', 'NN'),
#   ('remains', 'VBZ'),
#   ('day', 'NN'),
#   ('even', 'RB'),
#   ('used', 'VBD'),
#   ('heavily', 'RB'),
#   ('charger', 'JJR'),
#   ('box', 'NN'),
#   ('ok', 'IN'),
#   ('w', 'NN'),
#   ('could', 'MD'),
#   ('nothing', 'NN'),
#   ('like', 'IN'),
#   ('anything', 'NN'),
#   ('overall', 'JJ'),
#   ('excellent', 'JJ'),
#   ('product', 'NN'),
#   ('comfortable', 'JJ'),
#   ('use', 'NN'),
#   ('got', 'VBD'),
#   ('almost', 'RB'),
#   ('month', 'NN'),
#   ('back', 'RB'),
#   ('far', 'RB'),
#   ('goodread', 'NN')],
#  [('ultimate', 'JJ'),
#   ('performance', 'NN'),
#   ('camera', 'NN'),
#   ('superb', 'NN'),
#   ('battery', 'NN'),
#   ('backup', 'NN'),
#   ('also', 'RB'),
#   ('good', 'JJ'),
#   ('never', 'RB'),
#   ('saw', 'VBD'),
#   ('iphone', 'RB'),
#   ('give', 'JJ'),
#   ('much', 'JJ'),
#   ('battery', 'NN'),
#   ('backup', 'NN'),
#   ('one', 'CD'),
#   ('wana', 'NN'),
#   ('buy', 'VB'),
#   ('iphone', 'NN'),
#   ('definitely', 'RB'),
#   ('recommend', 'VBP'),
#   ('mobile', 'JJ'),
#   ('better', 'JJR'),
#   ('battery', 'NN'),
#   ('powerfull', 'NN'),
#   ('processer', 'NN'),
#   ('peak', 'NN'),
#   ('performance', 'NN'),
#   ('glorious', 'JJ'),
#   ('camera', 'NN'),
#   ('display', 'NN'),
#   ('also', 'RB'),
#   ('high', 'JJ'),
#   ('quality', 'NN'),
#   ('lcd', 'VBP'),
#   ('display', 'NN'),
#   ('u', 'JJ'),
#   ('money', 'NN'),
#   ('u', 'JJ'),
#   ('dont', 'NN'),
#   ('wana', 'NN'),
#   ('invest', 'VB'),
#   ('much', 'JJ'),
#   ('money', 'NN'),
#   ('go', 'VBP'),
#   ('iphone', 'RB'),
#   ('maximum', 'JJ'),
#   ('spec', 'NN'),
#   ('main', 'JJ'),
#   ('difference', 'NN'),
#   ('isread', 'NN')],
#  [('seller', 'NN'),
#   ('supercomnet', 'NN'),
#   ('trust', 'NN'),
#   ('grown', 'VBN'),
#   ('deeper', 'RBR'),
#   ('thanks', 'NNS'),
#   ('genuine', 'JJ'),
#   ('product', 'NN'),
#   ('package', 'NN'),
#   ('came', 'VBD'),
#   ('packed', 'VBN'),
#   ('perfectly', 'RB'),
#   ('box', 'JJ'),
#   ('sealed', 'VBN'),
#   ('gave', 'VBD'),
#   ('big', 'JJ'),
#   ('relief', 'NN'),
#   ('apple', 'NN'),
#   ('need', 'NN'),
#   ('introduction', 'NN'),
#   ('since', 'IN'),
#   ('dominant', 'JJ'),
#   ('market', 'NN'),
#   ('player', 'NN'),
#   ('love', 'VB'),
#   ('way', 'NN'),
#   ('iphone', 'NN'),
#   ('stand', 'VBP'),
#   ('boldly', 'RB'),
#   ('moment', 'NN'),
#   ('took', 'VBD'),
#   ('box', 'NN'),
#   ('could', 'MD'),
#   ('feel', 'VB'),
#   ('premium', 'JJ'),
#   ('intensity', 'NN'),
#   ('body', 'NN'),
#   ('remarkable', 'JJ'),
#   ('crafted', 'VBD'),
#   ('giving', 'VBG'),
#   ('elite', 'JJ'),
#   ('vibe', 'NN'),
#   ('camera', 'NN'),
#   ('die', 'NN'),
#   ('phone', 'NN'),
#   ('beatread', 'NN')],
#  [('cant', 'JJ'),
#   ('beat', 'NN'),
#   ('software', 'NN'),
#   ('hardware', 'NN'),
#   ('integration', 'NN'),
#   ('appleperforms', 'NNS'),
#   ('like', 'IN'),
#   ('beast', 'NN'),
# ...
#   ('phone', 'NN'),
#   ('camera', 'NN'),
#   ('thaaru', 'NN'),
#   ('maaru', 'NN'),
#   ('night', 'NN'),
#   ('la', 'NN'),
#   ('photo', 'NN'),
#   ('pudicha', 'NN'),
#   ('kooda', 'NN'),
#   ('pakkkava', 'NN'),
#   ('semmaya', 'JJ'),
#   ('pagal', 'JJ'),
#   ('la', 'NN'),
#   ('pudicha', 'NN'),
#   ('madhiri', 'FW'),
#   ('irukku', 'NN'),
#   ('rate', 'NN'),
#   ('ku', 'NN'),
#   ('aetha', 'IN'),
#   ('quality', 'NN'),
#   ('noiseless', 'JJ'),
#   ('voice', 'NN'),
#   ('touch', 'JJ'),
#   ('summa', 'NN'),
#   ('dhosa', 'NN'),
#   ('kallula', 'NN'),
#   ('pota', 'NN'),
#   ('butter', 'NN'),
#   ('madhiri', 'NN'),
#   ('vazhukkinu', 'NN'),
#   ('oduthu', 'NN'),
#   ('lovely', 'RB'),
#   ('phoneread', 'JJ')],
#  [('pathetic', 'JJ'),
#   ('experience', 'NN'),
#   ('flipkart', 'NN'),
#   ('cheating', 'VBG'),
#   ('people', 'NNS'),
#   ('promised', 'VBD'),
#   ('exchange', 'NN'),
#   ('value', 'NN'),
#   ('executive', 'NN'),
#   ('asked', 'VBD'),
#   ('pay', 'VB'),
#   ('cash', 'NN'),
#   ('delivery', 'NN'),
#   ('stupid', 'JJ'),
#   ('excuse', 'IN'),
#   ('phone', 'NN'),
#   ('failed', 'VBD'),
#   ('promise', 'NN'),
#   ('paid', 'VBN'),
#   ('money', 'NN'),
#   ('gift', 'NN'),
#   ('wifebut', 'NN'),
#   ('cheating', 'VBG'),
#   ('request', 'NN'),
#   ('take', 'VB'),
#   ('action', 'NN'),
#   ('else', 'RB'),
#   ('order', 'NN'),
#   ('againread', 'NN')],
#  [('absolute', 'JJ'), ('phone', 'NN'), ('read', 'NN')],
#  [('value', 'NN'), ('money', 'NN'), ('read', 'VB')],
#  [('good', 'JJ'), ('productread', 'NN')],
#  [('flipkart', 'RB'),
#   ('packing', 'VBG'),
#   ('soo', 'JJ'),
#   ('bad', 'JJ'),
#   ('hire', 'NN'),
#   ('low', 'JJ'),
#   ('level', 'NN'),
#   ('company', 'NN'),
#   ('shadofax', 'RB'),
#   ('give', 'JJ'),
#   ('poor', 'JJ'),
#   ('service', 'NN'),
#   ('device', 'NN'),
#   ('nice', 'RB'),
#   ('good', 'JJ'),
#   ('performanceread', 'NN')],
#  [('phone', 'NN'),
#   ('camera', 'NN'),
#   ('awesome', 'JJ'),
#   ('battery', 'NN'),
#   ('performance', 'NN'),
#   ('awesome', 'JJ'),
#   ('issue', 'NN'),
#   ('heating', 'VBG'),
#   ('charge', 'NN'),
#   ('using', 'VBG'),
#   ('camera', 'JJ'),
#   ('start', 'NN'),
#   ('getting', 'VBG'),
#   ('heating', 'VBG'),
#   ('badlyread', 'NN')],
#  [('little', 'JJ'),
#   ('worried', 'JJ'),
#   ('display', 'NN'),
#   ('buying', 'VBG'),
#   ('coz', 'NN'),
#   ('low', 'JJ'),
#   ('resolution', 'NN'),
#   ('lcd', 'NN'),
#   ('type', 'NN'),
#   ('using', 'VBG'),
#   ('hand', 'NN'),
#   ('took', 'VBD'),
#   ('away', 'RB'),
#   ('high', 'JJ'),
#   ('quality', 'NN'),
#   ('lcd', 'VBP'),
#   ('display', 'NN'),
#   ('resolution', 'NN'),
#   ('perfect', 'JJ'),
#   ('wouldnt', 'NN'),
#   ('notice', 'NN'),
#   ('pixelated', 'VBD'),
#   ('object', 'JJ'),
#   ('screen', 'NN'),
#   ('everything', 'NN'),
#   ('else', 'RB'),
#   ('phone', 'NN'),
#   ('without', 'IN'),
#   ('doubt', 'NN'),
#   ('best', 'JJS'),
#   ('industryvery', 'NN'),
#   ('happy', 'JJ'),
#   ('purchaseios', 'NNS'),
#   ('experience', 'NN'),
#   ('awesomeread', 'NN')],
#  [('got', 'VBD'),
#   ('fresh', 'JJ'),
#   ('piece', 'NN'),
#   ('brand', 'NN'),
#   ('new', 'JJ'),
#   ('trustable', 'JJ'),
#   ('supplier', 'NN'),
#   ('go', 'VBP'),
#   ('flipkart', 'RB'),
#   ('gave', 'VBD'),
#   ('best', 'JJS'),
#   ('rate', 'NN'),
#   ('local', 'JJ'),
#   ('shop', 'NN'),
#   ('site', 'NN'),
#   ('alsoread', 'NN')],
#  [('top', 'JJ'), ('notch', 'NN'), ('quality', 'NN'), ('phoneread', 'NN')],
#  [('good', 'JJ'),
#   ('delivered', 'VBN'),
#   ('well', 'RB'),
#   ('time', 'NN'),
#   ('thank', 'JJ'),
#   ('flipkartread', 'NN')],
#  [('must', 'MD'), ('buyread', 'VB')],
#  [('green', 'JJ'), ('beautyread', 'NN')],
#  [('goodread', 'NN')],
#  [('recieved', 'VBN'),
#   ('defective', 'JJ'),
#   ('product', 'NN'),
#   ('later', 'RBR'),
#   ('flipkart', 'RB'),
#   ('given', 'VBN'),
#   ('replacement', 'NN'),
#   ('recieved', 'VBD'),
#   ('good', 'JJ'),
#   ('one', 'CD'),
#   ('happy', 'JJ'),
#   ('switch', 'NN'),
#   ('android', 'NN'),
#   ('io', 'NN'),
#   ('im', 'NN'),
#   ('enjoying', 'VBG'),
#   ('everything', 'NN'),
#   ('mble', 'JJ'),
#   ('reached', 'VBN'),
#   ('expectationread', 'NN')],
#  [('delivery', 'NN'),
#   ('fast', 'RB'),
#   ('happy', 'JJ'),
#   ('iphone', 'NN'),
#   ('performance', 'NN'),
#   ('unbelievable', 'JJ'),
#   ('thank', 'NN'),
#   ('flipkartread', 'NN')],
#  [('dream', 'NN'),
#   ('become', 'NN'),
#   ('truesuprb', 'JJ'),
#   ('grip', 'JJ'),
#   ('smooth', 'NN'),
#   ('processesloved', 'VBD'),
#   ('itread', 'JJ')],
#  [('scared', 'JJ'),
#   ('order', 'NN'),
#   ('flipkart', 'VBD'),
#   ('many', 'JJ'),
#   ('complained', 'VBD'),
#   ('used', 'JJ'),
#   ('product', 'NN'),
#   ('sold', 'VBN'),
#   ('however', 'RB'),
#   ('hope', 'VBP'),
#   ('ordered', 'JJ'),
#   ('flipkart', 'NN'),
#   ('got', 'VBD'),
#   ('original', 'JJ'),
#   ('unused', 'JJ'),
#   ('iphone', 'NN'),
#   ('year', 'NN'),
#   ('apple', 'NN'),
#   ('warranty', 'NN'),
#   ('far', 'RB'),
#   ('issue', 'NN'),
#   ('coming', 'VBG'),
#   ('iphone', 'RB'),
#   ('known', 'VBN'),
#   ('everyone', 'NN'),
#   ('awesome', 'JJ'),
#   ('phone', 'NN'),
#   ('performance', 'NN'),
#   ('lag', 'NN'),
#   ('even', 'RB'),
#   ('keep', 'VB'),
#   ('apps', 'NN'),
#   ('open', 'JJ'),
#   ('state', 'NN'),
#   ('camera', 'NN'),
#   ('top', 'NN'),
#   ('notch', 'NN'),
#   ('worth', 'IN'),
#   ('buy', 'VB'),
#   ('come', 'JJ'),
#   ('budgetread', 'NN')],
#  [('awesomeread', 'NN')],
#  [('goodread', 'NN')],
#  [('decent', 'JJ'),
#   ('smartphone', 'NN'),
#   ('superb', 'NN'),
#   ('camera', 'NN'),
#   ('extraordinary', 'JJ'),
#   ('performance', 'NN'),
#   ('negative', 'JJ'),
#   ('side', 'NN'),
#   ('towards', 'NNS'),
#   ('battery', 'NN'),
#   ('could', 'MD'),
#   ('betterread', 'VB')],
#  [('super', 'JJ'), ('productread', 'NN')],
#  [('woww', 'NN'),
#   ('phone', 'NN'),
#   ('thisjust', 'NN'),
#   ('awesomethank', 'NN'),
#   ('flipkartmy', 'NN'),
#   ('phone', 'NN'),
#   ('battery', 'NN'),
#   ('awesomei', 'NN'),
#   ('didnt', 'NN'),
#   ('use', 'NN'),
#   ('much', 'JJ'),
#   ('battery', 'NN'),
#   ('tooo', 'NN'),
#   ('goodfrom', 'NN'),
#   ('fully', 'RB'),
#   ('daysbuy', 'VB'),
#   ('good', 'JJ'),
#   ('battery', 'NN'),
#   ('read', 'NN')],
#  [('iphone', 'NN'), ('proforming', 'VBG'), ('exelentread', 'NN')],
#  [('rounder', 'NN'),
#   ('phone', 'NN'),
#   ('review', 'NN'),
#   ('written', 'VBN'),
#   ('iphone', 'NN'),
#   ('problem', 'NN'),
#   ('box', 'NN'),
#   ('charger', 'NN'),
#   ('take', 'VB'),
#   ('decade', 'NN'),
#   ('charge', 'NN'),
#   ('phone', 'NN'),
#   ('buying', 'VBG'),
#   ('watt', 'NN'),
#   ('charger', 'NN'),
#   ('option', 'NN'),
#   ('even', 'RB'),
#   ('get', 'VB'),
#   ('watt', 'JJ'),
#   ('wireless', 'NN'),
#   ('charger', 'NN'),
#   ('qi', 'NN'),
#   ('type', 'NN'),
#   ('rest', 'NN'),
#   ('assured', 'VBN'),
#   ('phoneread', 'NN')],
#  [('firstly', 'RB'),
#   ('thank', 'JJ'),
#   ('flipkart', 'NN'),
#   ('quick', 'JJ'),
#   ('delivery', 'NN'),
#   ('tough', 'JJ'),
#   ('situation', 'NN'),
#   ('pandemic', 'RB'),
#   ('would', 'MD'),
#   ('like', 'VB'),
#   ('mention', 'NN'),
#   ('first', 'RB'),
#   ('impression', 'NN'),
#   ('device', 'NN'),
#   ('awesome', 'JJ'),
#   ('beyond', 'IN'),
#   ('expectation', 'NN'),
#   ('ill', 'NN'),
#   ('going', 'VBG'),
#   ('review', 'NN'),
#   ('rating', 'NN'),
#   ('later', 'RB'),
#   ('using', 'VBG'),
#   ('monthread', 'NN')],
#  [('lcd', 'NN'),
#   ('display', 'NN'),
#   ('cost', 'NN'),
#   ('something', 'NN'),
#   ('unacceptablecould', 'JJ'),
#   ('included', 'VBD'),
#   ('watt', 'JJ'),
#   ('charger', 'NN'),
#   ('box', 'NN'),
#   ('rather', 'RB'),
#   ('wattotherwise', 'JJ'),
#   ('performance', 'NN'),
#   ('camera', 'NN'),
#   ('goodread', 'NN')],
#  [('vry', 'NN'), ('nice', 'JJ'), ('productread', 'NN')],
#  [('happyread', 'NN')],
#  [('best', 'JJS'), ('marketread', 'NN')],
#  [('fragile', 'JJ'), ('bodyread', 'NN')],
#  [('classy', 'JJ'),
#   ('phone', 'NN'),
#   ('highly', 'RB'),
#   ('recommendedread', 'JJ')],
#  [('iphone', 'NN'),
#   ('iphone', 'NN'),
#   ('nothing', 'NN'),
#   ('beat', 'JJ'),
#   ('class', 'NN'),
#   ('uniqueness', 'NN'),
#   ('apple', 'NN'),
#   ('closed', 'VBD'),
#   ('environment', 'NN'),
#   ('got', 'VBD'),
#   ('gr', 'JJ'),
#   ('price', 'NN'),
#   ('point', 'NN'),
#   ('thr', 'NN'),
#   ('various', 'JJ'),
#   ('offer', 'NN'),
#   ('flipkart', 'JJ'),
#   ('dont', 'NN'),
#   ('think', 'NN'),
#   ('twice', 'RB'),
#   ('buy', 'VBP'),
#   ('asapread', 'JJ')],
#  [('got', 'NNS'), ('rsread', 'VBP')],
#  [('nothing', 'NN'), ('match', 'NN'), ('iphone', 'NN'), ('read', 'NN')],
#  [('first', 'RB'),
#   ('iphone', 'NN'),
#   ('really', 'RB'),
#   ('love', 'VB'),
#   ('appleread', 'NN')],
#  [('camera', 'NN'),
#   ('best', 'JJS'),
#   ('also', 'RB'),
#   ('got', 'VBD'),
#   ('good', 'JJ'),
#   ('discount', 'NN'),
#   ('via', 'IN'),
#   ('hdfc', 'JJ'),
#   ('card', 'NN'),
#   ('got', 'VBD'),
#   ('product', 'NN'),
#   ('rsread', 'NN')],
#  [('ultimate', 'JJ'), ('super', 'NN'), ('smoothread', 'NN')],
#  [('well', 'RB'),
#   ('got', 'RB'),
#   ('brand', 'NN'),
#   ('new', 'JJ'),
#   ('phone', 'NN'),
#   ('flipkart', 'NN'),
#   ('utmost', 'NN'),
#   ('concern', 'NN'),
#   ('ever', 'RB'),
#   ('since', 'IN'),
#   ('ordered', 'VBN'),
#   ('phone', 'NN'),
#   ('negative', 'JJ'),
#   ('review', 'NN'),
#   ('made', 'VBD'),
#   ('past', 'JJ'),
#   ('night', 'NN'),
#   ('sleepless', 'NN'),
#   ('although', 'IN'),
#   ('may', 'MD'),
#   ('one', 'CD'),
#   ('fortunate', 'VB'),
#   ('one', 'CD'),
#   ('got', 'VBD'),
#   ('new', 'JJ'),
#   ('phone', 'NN'),
#   ('one', 'CD'),
#   ('le', 'NN'),
#   ('star', 'NN'),
#   ('late', 'JJ'),
#   ('delevery', 'NN'),
#   ('well', 'RB'),
#   ('bit', 'RB'),
#   ('low', 'JJ'),
#   ('battery', 'NN'),
#   ('performance', 'NN'),
#   ('expected', 'VBN'),
#   ('rest', 'RB'),
#   ('great', 'JJ'),
#   ('product', 'NN'),
#   ('far', 'RB'),
#   ('appleread', 'JJ')],
#  [('camera', 'NN'), ('goodread', 'NN')],
#  [('nice', 'JJ'), ('phoneread', 'NN')],
#  [('superb', 'NN'),
#   ('phone', 'NN'),
#   ('packaging', 'NN'),
#   ('product', 'NN'),
#   ('gud', 'NN'),
#   ('read', 'NN')],
#  [('please', 'VB'),
#   ('req', 'NN'),
#   ('dont', 'JJ'),
#   ('buy', 'NN'),
#   ('anything', 'NN'),
#   ('flipkarti', 'JJ'),
#   ('buy', 'VB'),
#   ('iphone', 'NN'),
#   ('red', 'JJ'),
#   ('gb', 'NN'),
#   ('firstly', 'RB'),
#   ('face', 'VBP'),
#   ('phone', 'NN'),
#   ('heating', 'VBG'),
#   ('issue', 'NN'),
#   ('flipkart', 'RB'),
#   ('never', 'RB'),
#   ('try', 'VB'),
#   ('hrlp', 'NN'),
#   ('proformance', 'NN'),
#   ('smartphone', 'NN'),
#   ('aproxx', 'NN'),
#   ('zero', 'CD'),
#   ('better', 'JJR'),
#   ('picture', 'NN'),
#   ('quality', 'NN'),
#   ('beter', 'NN'),
#   ('processing', 'VBG'),
#   ('power', 'NN'),
#   ('take', 'VB'),
#   ('hr', 'NN'),
#   ('go', 'VB'),
#   ('percent', 'JJ'),
#   ('batterymy', 'NN'),
#   ('money', 'NN'),
#   ('got', 'VBD'),
#   ('wasted', 'VBN'),
#   ('productread', 'NN')],
#  [('good', 'JJ'), ('phone', 'NN'), ('camera', 'NN'), ('batteryread', 'NN')],
#  [('good', 'JJ'),
#   ('switched', 'VBD'),
#   ('android', 'JJ'),
#   ('iphone', 'NN'),
#   ('yearsthe', 'NN'),
#   ('notch', 'NN'),
#   ('big', 'JJ'),
#   ('considering', 'VBG'),
#   ('third', 'JJ'),
#   ('model', 'NN'),
#   ('apple', 'NN'),
#   ('havent', 'NN'),
#   ('done', 'VBN'),
#   ('anything', 'NN'),
#   ('big', 'JJ'),
#   ('notch', 'NN'),
#   ('deviceread', 'NN')],
#  [('adopter', 'NN'), ('workingread', 'NN')],
#  [('worth', 'JJ'), ('every', 'DT'), ('pennyread', 'NN')],
#  [('superb', 'NN'), ('phoneread', 'NN')],
#  [('apple', 'NN'),
#   ('fan', 'NN'),
#   ('past', 'IN'),
#   ('using', 'VBG'),
#   ('oneplus', 'NN'),
#   ('came', 'VBD'),
#   ('back', 'RB'),
#   ('apple', 'NN'),
#   ('iphone', 'NN'),
#   ('loving', 'VBG'),
#   ('itread', 'NN')],
#  [('awesome', 'JJ'),
#   ('phone', 'NN'),
#   ('price', 'NN'),
#   ('lagging', 'VBG'),
#   ('issue', 'NN'),
#   ('whatsoever', 'WRB'),
#   ('resolution', 'NN'),
#   ('bit', 'RB'),
#   ('low', 'JJ'),
#   ('doesnt', 'NN'),
#   ('feel', 'NN'),
#   ('likecamera', 'RB'),
#   ('fantastic', 'JJ'),
#   ('mp', 'NN'),
#   ('front', 'NN'),
#   ('mp', 'NN'),
#   ('back', 'RB'),
#   ('additional', 'JJ'),
#   ('wide', 'JJ'),
#   ('angle', 'NN'),
#   ('camera', 'NN'),
#   ('smooth', 'CC'),
#   ('k', 'NN'),
#   ('recording', 'VBG'),
#   ('fps', 'JJ'),
#   ('quite', 'RB'),
#   ('amazingspeaker', 'NN'),
#   ('louder', 'RBR'),
#   ('love', 'NN'),
#   ('phoneread', 'NN')],
#  [('nyccread', 'NN')],
#  [('best', 'JJS'),
#   ('ever', 'RB'),
#   ('awsome', 'JJ'),
#   ('camera', 'NN'),
#   ('battery', 'NN'),
#   ('smooth', 'CD'),
#   ('osread', 'NN')],
#  [('amazingread', 'NN')],
#  [('good', 'JJ'), ('phoneread', 'NN')],
#  [('value', 'NN'),
#   ('moneywith', 'VBZ'),
#   ('super', 'JJR'),
#   ('added', 'VBN'),
#   ('featuresread', 'NN')],
#  [('awesome', 'JJ'), ('read', 'NN')],
#  [('superb', 'NN'),
#   ('phone', 'NN'),
#   ('awesome', 'JJ'),
#   ('battery', 'NN'),
#   ('display', 'NN'),
#   ('read', 'NN')],
#  [('amazing', 'VBG'), ('phone', 'NN'), ('great', 'JJ'), ('cameraread', 'NN')],
#  [('best', 'JJS'), ('switch', 'NN'), ('iphone', 'NN'), ('androidread', 'NN')],
#  [('built', 'VBN'),
#   ('quality', 'NN'),
#   ('poor', 'JJ'),
#   ('personally', 'RB'),
#   ('examined', 'VBN'),
#   ('x', 'NNP'),
#   ('screen', 'JJ'),
#   ('body', 'NN'),
#   ('side', 'JJ'),
#   ('button', 'NN'),
#   ('everything', 'NN'),
#   ('quality', 'NN'),
#   ('le', 'NN'),
#   ('shame', 'NN'),
#   ('iphone', 'NN'),
#   ('makersread', 'NN')],
#  [('good', 'JJ'),
#   ('product', 'NN'),
#   ('nd', 'NN'),
#   ('dont', 'JJ'),
#   ('buy', 'NN'),
#   ('another', 'DT'),
#   ('place', 'NN'),
#   ('bcoz', 'NN'),
#   ('defective', 'JJ'),
#   ('product', 'NN'),
#   ('purchase', 'NN'),
#   ('flipkart', 'JJ'),
#   ('thank', 'JJ'),
#   ('flipkart', 'NN'),
#   ('read', 'NN')],
#  [('first', 'JJ'),
#   ('time', 'NN'),
#   ('apple', 'NN'),
#   ('user', 'NN'),
#   ('fulfilled', 'VBD'),
#   ('expectation', 'NN'),
#   ('pubg', 'NN'),
#   ('loaded', 'VBD'),
#   ('second', 'JJ'),
#   ('camera', 'NN'),
#   ('bestread', 'NN')],
#  [('phone', 'NN'),
#   ('started', 'VBD'),
#   ('restarting', 'VBG'),
#   ('every', 'DT'),
#   ('min', 'NN'),
#   ('itselfread', 'NN')],
#  [('best', 'JJS'),
#   ('mobile', 'NN'),
#   ('ever', 'RB'),
#   ('used', 'VBD'),
#   ('best', 'JJS'),
#   ('xameraread', 'NN')],
#  [('camera', 'NN'), ('batterydisplayread', 'NN')],
#  [('nice', 'JJ'),
#   ('looking', 'VBG'),
#   ('phone', 'NN'),
#   ('super', 'NN'),
#   ('camera', 'NN'),
#   ('quality', 'NN'),
#   ('usual', 'JJ'),
#   ('apple', 'NN'),
#   ('hardware', 'NN'),
#   ('awesomeread', 'NN')],
#  [('within', 'IN'),
#   ('month', 'NN'),
#   ('need', 'VBP'),
#   ('replace', 'VB'),
#   ('partsread', 'NN')],
#  [('awsomeread', 'NN')],
#  [('simply', 'RB'), ('awesomeread', 'JJ')],
#  [('excellent', 'JJ'),
#   ('phone', 'NN'),
#   ('apple', 'NN'),
#   ('amazing', 'JJ'),
#   ('battery', 'NN'),
#   ('backup', 'NN'),
#   ('build', 'VBP'),
#   ('quality', 'NN'),
#   ('phenomenal', 'JJ'),
#   ('camera', 'NN'),
#   ('quality', 'NN'),
#   ('complaint', 'VBP'),
#   ('flipkart', 'NN'),
#   ('packaging', 'NN'),
#   ('packaging', 'NN'),
#   ('pathetic', 'JJ'),
#   ('phone', 'NN'),
#   ('box', 'NN'),
#   ('simply', 'RB'),
#   ('sealed', 'VBD'),
#   ('inside', 'JJ'),
#   ('flimsy', 'JJ'),
#   ('flipkart', 'NN'),
#   ('plastic', 'NN'),
#   ('bag', 'NN'),
#   ('delivered', 'VBN'),
#   ('expected', 'VBN'),
#   ('least', 'JJS'),
#   ('better', 'RBR'),
#   ('packaging', 'VBG'),
#   ('fragile', 'JJ'),
#   ('item', 'NN'),
#   ('also', 'RB'),
#   ('especially', 'RB'),
#   ('since', 'IN'),
#   ('piece', 'NN'),
#   ('got', 'VBD'),
#   ('first', 'JJ'),
#   ('batch', 'NN'),
#   ('iphone', 'NN'),
#   ('delivery', 'NN'),
#   ('india', 'NN'),
#   ('via', 'IN'),
#   ('prebooking', 'VBG'),
#   ('expected', 'VBN'),
#   ('care', 'NN'),
#   ('least', 'JJS'),
#   ('would', 'MD'),
#   ('given', 'VBN'),
#   ('star', 'VB'),
#   ('product', 'NN'),
#   ('read', 'NN')],
#  [('awesome', 'JJ'),
#   ('camera', 'NN'),
#   ('performance', 'NN'),
#   ('phone', 'NN'),
#   ('next', 'JJ'),
#   ('levelbattery', 'NN'),
#   ('backup', 'NN'),
#   ('quite', 'RB'),
#   ('goodhavent', 'JJ'),
#   ('used', 'VBN'),
#   ('muchwill', 'NN'),
#   ('write', 'JJ'),
#   ('battery', 'NN'),
#   ('daysread', 'NN')],
#  [('original', 'JJ'),
#   ('product', 'NN'),
#   ('apple', 'NN'),
#   ('security', 'NN'),
#   ('seal', 'VBP'),
#   ('pack', 'NN'),
#   ('flipcart', 'JJ'),
#   ('item', 'NN'),
#   ('missing', 'VBG'),
#   ('fir', 'NN'),
#   ('apple', 'NN'),
#   ('head', 'NN'),
#   ('phone', 'NN'),
#   ('charger', 'NN'),
#   ('requested', 'VBD'),
#   ('apple', 'NN'),
#   ('please', 'NN'),
#   ('add', 'VB'),
#   ('headphone', 'CD'),
#   ('chargerread', 'NN')],
#  [('good', 'JJ'),
#   ('phone', 'NN'),
#   ('apple', 'NN'),
#   ('battery', 'NN'),
#   ('far', 'RB'),
#   ('better', 'RBR'),
#   ('one', 'CD'),
#   ('kidney', 'NN'),
#   ('boy', 'NN'),
#   ('read', 'NN')],
#  [('love', 'NN'), ('itread', 'NN')],
#  [('good', 'JJ'),
#   ('giving', 'VBG'),
#   ('charger', 'NN'),
#   ('earphone', 'NN'),
#   ('read', 'NN')],
#  [('decided', 'VBD'),
#   ('buy', 'VB'),
#   ('iphone', 'NN'),
#   ('iphone', 'NN'),
#   ('xr', 'NN'),
#   ('using', 'VBG'),
#   ('week', 'NN'),
#   ('dont', 'NN'),
#   ('regret', 'JJ'),
#   ('itios', 'NNS'),
#   ('bad', 'JJ'),
#   ('use', 'NN'),
#   ('anroid', 'JJ'),
#   ('nice', 'JJ'),
#   ('phone', 'NN'),
#   ('awesome', 'JJ'),
#   ('cameraread', 'NN')]]

# %%
Adjective = []
Adverb = []
CordinatingConjunction = []
SubordinatingConjuction = []
Interjection = []
Noun = []
Verb = []
PersonalPronoun = []
predeterminer = []
Determiner = []

# %%
for value in pos:
  AdjectiveCount = 0
  AdverbCount = 0
  CordinatingConjunctionCount = 0
  SubordinatingConjuctionCount = 0
  InterjectionCount = 0
  NounCount = 0
  VerbCount = 0
  PersonalPronounCount = 0
  predeterminerCount = 0
  DeterminerCount = 0
  for word,tag in value:
    if tag == 'JJ':
      AdjectiveCount = AdjectiveCount + 1
    elif tag == 'RB':
      AdverbCount = AdverbCount + 1
    elif tag == 'CC':
      CordinatingConjunctionCount = CordinatingConjunctionCount + 1
    elif tag == 'UH':
      InterjectionCount = InterjectionCount + 1
    elif tag == 'NN':
      NounCount = NounCount + 1
    elif tag == 'VR':
      VerbCount = VerbCount + 1
    elif tag == 'PRP':
      PersonalPronounCount = PersonalPronounCount + 1
    elif tag == 'PDT':
      predeterminerCount = predeterminerCount + 1
    elif tag == 'DT':
      DeterminerCount = DeterminerCount + 1
    elif tag == 'IN':
      SubordinatingConjuctionCount = SubordinatingConjuctionCount + 1
  Adjective.append(AdjectiveCount)
  Adverb.append(AdverbCount)
  CordinatingConjunction.append(CordinatingConjunctionCount)
  Interjection.append(InterjectionCount)
  Noun.append(NounCount)
  Verb.append(VerbCount)
  PersonalPronoun.append(PersonalPronounCount)
  predeterminer.append(predeterminerCount)
  Determiner.append(DeterminerCount)
  SubordinatingConjuction.append(SubordinatingConjuctionCount)

# %%
df['Number of Adjectives'] = Adjective
df['Number of Adverbs'] = Adverb
df['Number of Cordinating Conjunctions'] = CordinatingConjunction
df['Number of Interjections'] = Interjection
df['Number of Nouns'] = Noun
df['Number of Verbs'] = Verb
df['Number of Personal Pronouns'] = PersonalPronoun
df['Number of Predeterminers'] = predeterminer
df['Number of Determiners'] = Determiner
df['Number of Subordinating Conjuctions'] = SubordinatingConjuction
df
# Out:
#          Glimpse of Review  ... Number of Subordinating Conjuctions
# 0                Brilliant  ...                                   0
# 1         Perfect product!  ...                                   0
# 2            Great product  ...                                   0
# 3        Worth every penny  ...                                   3
# 4              Good choice  ...                                   1
# ..                     ...  ...                                 ...
# 505       Perfect product!  ...                                   0
# 506  Mind-blowing purchase  ...                                   0
# 507              Brilliant  ...                                   0
# 508       Perfect product!  ...                                   0
# 509     Highly recommended  ...                                   0
#
# [510 rows x 13 columns]

# %% [markdown]
# # **Linguistic features**

# %% [markdown]
# **Number of right-branching nodes**

# %%
RightBranchingNodes = []
import spacy
nlp = spacy.load("en_core_web_sm")

for sentence in df['After Preprocessing']:
  doc = nlp(sentence)
  try:
    RightBranchingNodes.append(doc[0].n_rights)
  except:
    RightBranchingNodes.append('No')
df['Number of Right Branching Nodes'] = RightBranchingNodes

# %% [markdown]
# **Sentence Length**

# %%
df['Sentenece Length'] = df['Full Review'].apply(lambda x: len(x))
df
# Out:
#          Glimpse of Review  ... Sentenece Length
# 0                Brilliant  ...              219
# 1         Perfect product!  ...              123
# 2            Great product  ...              501
# 3        Worth every penny  ...              504
# 4              Good choice  ...              241
# ..                     ...  ...              ...
# 505       Perfect product!  ...              179
# 506  Mind-blowing purchase  ...               69
# 507              Brilliant  ...               16
# 508       Perfect product!  ...               56
# 509     Highly recommended  ...              162
#
# [510 rows x 15 columns]
